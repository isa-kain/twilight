# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import fits
from datetime import date, datetime, timedelta, timezone
from astroquery.jplhorizons import Horizons
import astropy.units as u
import pandas as pd
import xarray as xr
from tqdm import tqdm
import calendar
from matplotlib.patches import Rectangle
from astropy.coordinates import AltAz, EarthLocation, SkyCoord, get_body, get_sun
from astropy.time import Time
import multiprocessing

from utils import *

# %load_ext autoreload
# %autoreload 2

ephempath = '/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool/ephemeris-tables/'
toipath = '/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool'
# Out:
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: astropy.samp was deprecated in version 8.0 and will be removed in a future version; please use pyvo.samp instead. [astropy.samp]

# %% [markdown]
# ### Functions bank

# %%
date = now.strftime('%Y-%m-%d')
date
# Out:
# '2026-06-21'

# %%
def read_solar_ephemeris(datestr=None):
    '''
    Read pre-generated lookup table of solar ephemerides from Keck II. 
    User can input an optional date string (YYY-MM-DD) to pull ephemerides
    from this date; otherwise, the code pulls ephemerides from today.
    '''
    
    # Parse date if given by user
    if datestr is not None:
        date = datetime.strptime(datestr, '%Y-%m-%d')
        year = date.strftime('%Y')
    
    # Otherwise, use today's date
    else:
        now = datetime.now()
        date = now.strftime('%Y-%m-%d')
        year = now.strftime('%Y')
        
        
    # Read in solar ephemeris table from matching year
    ephem = pd.read_csv(f'{ephempath}/twilight_ephemerides_keckII_{year}.csv')
    
    
    # Identify row of ephemeris table that matches date
    try: 
        
        ix = ephem.index[ephem['Date'] == date].tolist()

        try: 
            assert len(ix)==1
            ix = ix[0]
        except: 
            print(f'Multiple rows for the same date. Something went wrong for the {date} ephemeris!')
            return 0

    except: 
        print(f'Solar ephemeris not available for {date}. Go make one.')
        return 0
    
    
    # Parse sunrise/sunset parameters from matching date
    sunset_UTC = ephem['sunset_UTC'][ix]
    sunset_az = ephem['sunset_az'][ix]
    sunset_el = ephem['sunset_el'][ix]
    sunset_ra = ephem['sunset_ra'][ix]
    sunset_dec = ephem['sunset_dec'][ix]
    sunset_sidereal = ephem['sunset_sidereal'][ix]
    
    sunrise_UTC = ephem['sunrise_UTC'][ix]
    sunrise_az = ephem['sunrise_az'][ix]
    sunrise_el = ephem['sunrise_el'][ix]
    sunrise_ra = ephem['sunrise_ra'][ix]
    sunrise_dec = ephem['sunrise_dec'][ix]
    sunrise_sidereal = ephem['sunrise_sidereal'][ix]
    
    print('Sunset time:', sunset_UTC)
    print('Sunrise time:', sunrise_UTC)
    
    return sunset_UTC, sunset_az, sunset_el, sunset_ra, sunset_dec, sunset_sidereal, \
            sunrise_UTC, sunrise_az, sunrise_el, sunrise_ra, sunrise_dec, sunrise_sidereal
    


def keckII_pointing_limits(az, el):
    '''
    Returns if given az, el is within Keck II telescope pointing constraints.
    See documentation: https://www2.keck.hawaii.edu/inst/common/TelLimits.html
    '''
    
    # Check against nasmyth deck pointing limit
    if (az >= 185.3) and (az <= 332.8):
        if el >= 36.8:
            return True
        else:
            return False
        
    # Check against shutter vignetting
    else:
        if el >= 18.0:
            return True
        else:
            return False
        
        
def twilight_pointing_limits(az, sun_az, az_sep=45.):
    '''
    Check if telescope az is >=45˚ from the sun. (az, sun_az units in degrees)
    Since telescope shutters are vertical, el angle does NOT matter.
    '''

    # Find difference between sun, telescope az angles
    if az > 180.:
        az = az - 360.

    if sun_az > 180.:
        sun_az = sun_az - 360.
    
    az_diff = np.abs(az-sun_az)
    print(az_diff)
                
    
    # Check if input az obeys twilight pointing constraints
    if az_diff < az_sep: 
        return False
    else: 
        return True
    


    
def query_JPL_horizons(start, end):
    '''
    start: datetime object, year month day 03:00:00
    start: datetime object, year month day 18:00:00
    '''

    # Set epoch to query
    epoch =  {'start':start.strftime('%Y-%m-%d %H:%M:%S'), 'stop':end.strftime('%Y-%m-%d %H:%M:%S'), 'step':'1m'}

    
    # Send query
    obj = Horizons(id='sun', location='T17', epochs=epoch) # t17 = Keck II
    result = obj.ephemerides(skip_daylight=True)

    if not (result['solar_presence'][0]=='C') & (result['solar_presence'][-1]=='C'):
        print('FUCKED UP!', epoch)

        
    # Extract sunset params
    sunset_time = result['datetime_str'][0] # datetime string, e.g. '2025-Jan-01 04:04'
    sunset_az = result['AZ'][0] # deg
    sunset_el = result['EL'][0] # deg
    sunset_ra = result['RA_app'][0] # deg
    sunset_dec = result['DEC_app'][0] # deg
    sunset_sidereal = result['siderealtime'][0] # hours

    
    # Extract sunrise params
    sunrise_time = result['datetime_str'][-1] # datetime string, e.g. '2025-Jan-01 04:04'
    sunrise_az = result['AZ'][-1] # deg
    sunrise_el = result['EL'][-1] # deg
    sunrise_ra = result['RA_app'][-1] # deg
    sunrise_dec = result['DEC_app'][-1] # deg
    sunrise_sidereal = result['siderealtime'][-1] # hours

    
    # Return all params as single row
    return start.strftime('%Y-%m-%d'), sunset_time, sunset_az, sunset_el, sunset_ra, sunset_dec, \
            sunset_sidereal, sunrise_time, sunrise_az, sunrise_el, sunrise_ra, sunrise_dec, sunrise_sidereal



def grab_ss_trace(objname, site, sunset_UTC, sunrise_UTC):
    '''
    objname :: string name of major SS body (e.g. Jupiter, Neptune, NOT any of the moons)
    site :: EarthLocation object
    sunset_UTC :: datetime object
    '''
    
    # Generate list of times throughout night to check where SS object is in the sky
    sample_times = Time( pd.date_range(start=sunset_UTC, end=sunrise_UTC, periods=30).to_numpy() )
    obj_az = np.zeros(len(sample_times))
    obj_el = np.zeros(len(sample_times)) 


    # Grab object az,el location at each timestamp
    for i, time in enumerate(sample_times):

        obj_coord = get_body(objname, time=time, location=site) 
        obj_coord_altaz = obj_coord.transform_to(AltAz(obstime=time, location=keck))

        obj_az[i] = obj_coord_altaz.az.value
        obj_el[i] = obj_coord_altaz.alt.value
        
        # If object not effectively visible with Keck II, mask values with NaNs
        if not keckII_pointing_limits(obj_az[i], obj_el[i]):
            obj_el[i] = np.nan

#     # Mask timestamps with NaNs where el < 18deg
#     obj_el[obj_el < 18.] = np.nan
    
    # Return location
    return obj_az, obj_el, sample_times



def is_target_up_morn_twi(sunrise_dt, obj_coord, site):
    '''
    sunrise_dt :: datetime object, datetime of sunrise at site
    obj_coord ::  SkyCoord (ICRS) of target object
    site :: EarthLocation object of observing site
    '''

    # Sample target visibility at 15 minute increments during hour before sunrise
    twilight_samptimes = [sunrise_dt - timedelta(minutes=15*x) for x in range(0,5)]


    # Check if target is within Keck II pointing limits at each sample time
    sampled_visibility = np.full(len(twilight_samptimes), False)

    for j, time in enumerate(twilight_samptimes):

        # What is az/el location of TOI at given time? 
        obj_coord_azel = obj_coord.transform_to(AltAz(obstime=Time(time), location=site))
        obj_az = obj_coord_azel.az.value
        obj_el = obj_coord_azel.alt.value

        # Is it within telescope pointing constraints?
        vis = keckII_pointing_limits(obj_az, obj_el) # returns True/False
        sampled_visibility[j] = vis

    # is object up for at least 3 of the 5 sampled times?
    is_up = (np.sum(sampled_visibility) >= 3.) # True/False -- FIXME is this the right litmus?
    
    return is_up




def make_azel_plot(sunset_UTC, sunset_az, sunrise_UTC, sunrise_az, obj_az, obj_el, trace_times, obj_label='Target'):
    
    # Initialize plot
    fig, ax = plt.subplots(1, 1, figsize=(5, 7), subplot_kw={'projection': 'polar'}, layout='constrained')
    plt.tight_layout()
    
    ax.set_rmax(0.)
    ax.set_rmin(90.)
    ax.grid(True)
    ax.set_theta_zero_location('N')

    ax.annotate('N', (np.deg2rad(10.), -6.), xycoords='data', fontsize=18, annotation_clip=False, fontweight='bold')
    ax.annotate('S', (np.deg2rad(185.), -12.), xycoords='data', fontsize=18, annotation_clip=False, fontweight='bold')
    ax.annotate('E', (np.deg2rad(85.), -14.), xycoords='data', fontsize=18, annotation_clip=False, fontweight='bold')
    ax.annotate('W', (np.deg2rad(275.), -6.), xycoords='data', fontsize=18, annotation_clip=False, fontweight='bold')

    # Calculate Keck II pointing limits
    linspace_az = np.linspace(0., 2.*np.pi, 100)

    tel_constraints_el = np.full_like(linspace_az, 18.0)
    tel_constraints_el[(linspace_az >= np.deg2rad(185.3)) & (linspace_az <= np.deg2rad(332.8))] = 36.8

    horizon_el = np.zeros_like(linspace_az)
    
    # Plot Keck II pointing limits
    ax.plot(linspace_az, tel_constraints_el, ls='--', color='gray')
    ax.fill_between(linspace_az, horizon_el, tel_constraints_el, color='gray', alpha=0.3, label='Keck II limits')
    
    # Calculate twilight pointing constraints
    
    az_lolim = sunrise_az - 45.
    az_uplim = sunrise_az + 45.

    if az_lolim < 0:
        az_lolim += 360.
    if az_uplim > 360.:
        az_uplim %= 360.

    twi_constraints_el = np.full_like(linspace_az, 0.0)
    twi_constraints_el[(linspace_az > np.deg2rad(az_lolim)) & (linspace_az < np.deg2rad(az_uplim))] = 90.


    # Plot twilight pointing constraints
    ax.scatter(np.deg2rad(sunrise_az), 3., marker='*', color='r', edgecolor='k', s=200, label=f'Sunrise location ({sunrise_UTC} UTC)')

    ax.fill_between(linspace_az, horizon_el, twi_constraints_el, color='red', alpha=0.3, 
                label=f'Sunrise limits ({az_lolim:0.0f} < az < {az_uplim:0.0f})')
    
    # Find timestamps of when object rises & sets
    start_vis = np.where(np.isfinite(obj_el))[0][0] # index where object rises/observing window starts
    end_vis = np.where(np.isfinite(obj_el))[0][-1] # index where object sets/observing window ends
    print(start_vis, end_vis)
    
    # Plot trace of object across sky
    plt.plot(np.deg2rad(obj_az), obj_el, label=obj_label)
    plt.scatter(np.deg2rad(obj_az[start_vis]), obj_el[start_vis], marker='o', fc=None, ec='C0')
    plt.scatter(np.deg2rad(obj_az[end_vis]), obj_el[end_vis], marker='o', color='C0')
    
    # Annotate rise, set times of object
    t1 = trace_times[start_vis].strftime('%H:%M')
    t2 = trace_times[end_vis].strftime('%H:%M')
    
    ax.annotate(t1, (np.deg2rad(nep_az[start_vis])*1.02, nep_el[start_vis]*1.02), xycoords='data')
    ax.annotate(t2, (np.deg2rad(nep_az[end_vis])*1.02, nep_el[end_vis]*1.02), xycoords='data')

    # Set legend
    datestr = sunrise_UTC.split(' ')[0]
    fig.legend(title=f'Ephemeris {datestr}', frameon=True, fancybox=True, loc='upper center',
               title_fontproperties={'weight':'semibold', 'size':'large'})
    
    # Display
    return fig


def parse_datestring(datestr):
    '''
    Ingests string of unknown datetime format and checks it against a number of datetime formats:
    
    ** Year, month and day specified: **
    YYY-MM-DD > %Y-%m-%d
    YY-MM-DD > %y-%m-%d
    MM-DD-YYYY > %m-%d-%Y
    MM-DD-YY > %m-%d-%y
    mnth DD YYYY > %b %d %Y
    mnth DD YY > %b %d %y
    Month DD YYYY > %B %d %Y
    Month DD YY > %B %d %y
    
    ** Month and day only specified: **
    MM-DD > %m-%d
    mnth DD > %b %d
    month DD > %B %d
    
    ** User specifies current day: **
    Today
    Tonight
    Now
    '''
    
    # Write out datetime formats to check user input against
    list_of_dtformats_withyear = ['%Y-%m-%d', '%y-%m-%d', '%m-%d-%Y', '%m-%d-%y', '%b %d %Y', '%b %d %y', '%B %d %Y', '%B %d %y']
    list_of_dtformats_woutyear = ['%m-%d', '%b %d', '%B %d']
    list_of_dtformats_today = ['today', 'tonight', 'now']
    
    
    # Create datetime object for current day
    now = datetime.now()
    
    
    # Check entered datestring against strptime formats (year user-specified)
    for fmt in list_of_dtformats_withyear:    
        try:
            date = datetime.strptime(datestr, fmt)
            year = date.strftime('%Y') 
            print('User-entered observation date:', date)
        except ValueError:
            pass

        
    # Check entered datestring against strptime formats (year NOT user-specified)
    for fmt in list_of_dtformats_woutyear:    
        try:
            date = datetime.strptime(datestr, fmt)
            year = now.strftime('%Y') 
            date = date.replace(year=int(year))
            print('User-entered observation date:', date)
        except ValueError:
            pass
    
    # Maybe your user is overeager and specifies that they TODAY
    if any( fmt.casefold() in datestr.casefold() for fmt in list_of_dtformats_today ):
        date = now # contains current hour, minute, second, ect – shouldn't matter
        year = now.strftime('%Y')
    
    # If no formats matched, return ValueError; else, return datetime object and year string
    try:
        return date, year
    except NameError:
        raise ValueError('User-entered date format not recognized. Try again!')

# %% [markdown]
# ### Build sunrise/sunset time & location dictionary

# %% [markdown]
# #### Sandbox

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.time import Time
from tqdm import tqdm
from astroquery.jplhorizons import Horizons
import astropy.coordinates as co
import calendar
from datetime import datetime
from datetime import timedelta

# %%
# # Set year range to build dictionaries for

# start_year = 2026
# end_year = 2027

# start_time = '03:00:00' # end search time UTC
# end_time = '18:00:00' # start search time UTC



# # Iterate through each day of each year

# epochs = []

# for year in range(start_year, end_year+1):
    
#     for month in range(1, 12+1):
    
#         # year = 2018
#         # month = 1
    
#         num_days = calendar.monthrange(year, month)[1]
    
#         for day in range(1, num_days+1):
#             epochs.append( {'start':f'{year:02}-{month:02}-{day:02} {start_time}', 'stop':f'{year:02}-{month:02}-{day:02} {end_time}', 'step':'1m'} )
    
# print(len(epochs), epochs[0], epochs[-1])

# %%
# start_year = 2026
# end_year = 2027
year = 2025

# Make list of time ranges to query JPL Horizons with (UTC 3-18, 5pm thru 8am HT)

start_time = '03:00:00' # start search time UTC (evening)
end_time = '18:00:00' # end search time UTC (morning)

numdays = 365 + calendar.isleap(year) # year must be int
numdays

start_date = datetime.strptime(f'01/01/{year} {start_time}', '%d/%m/%Y %H:%M:%S')
start_datetimes = [start_date + timedelta(days=x) for x in range(numdays)]

end_date = datetime.strptime(f'01/01/{year} {end_time}', '%d/%m/%Y %H:%M:%S')
end_datetimes = [end_date + timedelta(days=x) for x in range(numdays)]

display(start_datetimes[-10:])
display(end_datetimes[-10:])
# Out:
# [datetime.datetime(2025, 12, 22, 3, 0),
#  datetime.datetime(2025, 12, 23, 3, 0),
#  datetime.datetime(2025, 12, 24, 3, 0),
#  datetime.datetime(2025, 12, 25, 3, 0),
#  datetime.datetime(2025, 12, 26, 3, 0),
#  datetime.datetime(2025, 12, 27, 3, 0),
#  datetime.datetime(2025, 12, 28, 3, 0),
#  datetime.datetime(2025, 12, 29, 3, 0),
#  datetime.datetime(2025, 12, 30, 3, 0),
#  datetime.datetime(2025, 12, 31, 3, 0)]
# [datetime.datetime(2025, 12, 22, 18, 0),
#  datetime.datetime(2025, 12, 23, 18, 0),
#  datetime.datetime(2025, 12, 24, 18, 0),
#  datetime.datetime(2025, 12, 25, 18, 0),
#  datetime.datetime(2025, 12, 26, 18, 0),
#  datetime.datetime(2025, 12, 27, 18, 0),
#  datetime.datetime(2025, 12, 28, 18, 0),
#  datetime.datetime(2025, 12, 29, 18, 0),
#  datetime.datetime(2025, 12, 30, 18, 0),
#  datetime.datetime(2025, 12, 31, 18, 0)]

# %%
## Query JPL Horizons for a single day

i = 0
start = start_datetimes[i]
end = end_datetimes[i]
epoch =  {'start':start.strftime('%d-%m-%Y %H:%M:%S'), 'stop':end.strftime('%d-%m-%Y %H:%M:%S'), 'step':'1m'}

print(start, end)

## Send query
obj = Horizons(id='sun', location='T17', epochs=epoch) # t17 = Keck II
result = obj.ephemerides(skip_daylight=True)

if not (result['solar_presence'][0]=='C') & (result['solar_presence'][-1]=='C'):
    print('FUCKED UP!', epoch)

display(result[:10])
# Out:
# 2025-01-01 03:00:00 2025-01-01 18:00:00
# <Table masked=True length=10>
# targetname    datetime_str      datetime_jd    ... alpha_true  PABLon   PABLat
#    ---            ---                d         ...    deg       deg      deg
#    str8          str17            float64      ...  float64   float64  float64
# ---------- ----------------- ----------------- ... ---------- -------- -------
#   Sun (10) 2025-Jan-01 04:04 2460676.669444445 ...        0.0 280.6405  0.0023
#   Sun (10) 2025-Jan-01 04:05 2460676.670138889 ...        0.0 280.6412  0.0023
#   Sun (10) 2025-Jan-01 04:06 2460676.670833333 ...        0.0 280.6419  0.0023
#   Sun (10) 2025-Jan-01 04:07 2460676.671527778 ...        0.0 280.6426  0.0023
#   Sun (10) 2025-Jan-01 04:08 2460676.672222222 ...        0.0 280.6433  0.0023
#   Sun (10) 2025-Jan-01 04:09 2460676.672916667 ...        0.0  280.644  0.0023
#   Sun (10) 2025-Jan-01 04:10 2460676.673611111 ...        0.0 280.6447  0.0023
#   Sun (10) 2025-Jan-01 04:11 2460676.674305555 ...        0.0 280.6454  0.0023
#   Sun (10) 2025-Jan-01 04:12       2460676.675 ...        0.0 280.6461  0.0023
#   Sun (10) 2025-Jan-01 04:13 2460676.675694444 ...        0.0 280.6468  0.0024

# %%
## Extract sunset params

sunset_time = result['datetime_str'][0] # datetime string, e.g. '2025-Jan-01 04:04'
sunset_az = result['AZ'][0] # deg
sunset_el = result['EL'][0] # deg
sunset_ra = result['RA_app'][0] # deg
sunset_dec = result['DEC_app'][0] # deg
sunset_sidereal = result['siderealtime'][0] # hours

## Extract sunrise params

sunrise_time = result['datetime_str'][-1] # datetime string, e.g. '2025-Jan-01 04:04'
sunrise_az = result['AZ'][-1] # deg
sunrise_el = result['EL'][-1] # deg
sunrise_ra = result['RA_app'][-1] # deg
sunrise_dec = result['DEC_app'][-1] # deg
sunrise_sidereal = result['siderealtime'][-1] # hours

# %% [markdown]
# #### Scriptify

# %%
# Set range of dates to query

year = 2027

start_time = '03:00:00'  # start search time UTC (evening, 5pm HT)
end_time = '18:00:00'  # end search time UTC (morning, 8am HT)

numdays = 365 + calendar.isleap(year)  # year must be int

# Make lists of datetime inputs

start_date = datetime.strptime(f'{year}-01-01 {start_time}',
                               '%Y-%m-%d %H:%M:%S')
start_datetimes = [start_date + timedelta(days=x) for x in range(numdays)]

end_date = datetime.strptime(f'{year}-01-01 {end_time}', '%Y-%m-%d %H:%M:%S')
end_datetimes = [end_date + timedelta(days=x) for x in range(numdays)]

# %%
# Make pandas dataframe to catch results

# 13 columns, numdays rows
# YYYY-MM-DD (str) % sunrise_time % sunrise_az % sunrise_el % sunrise_ra % sunrise_dec % sunrise_sidereal % […]

columns = ['Date', 'sunrise_UTC', 'sunrise_az', 'sunrise_el', 'sunrise_ra', 'sunrise_dec', 'sunrise_sidereal', \
            'sunset_UTC', 'sunset_az', 'sunset_el', 'sunset_ra', 'sunset_dec', 'sunset_sidereal']

df = pd.DataFrame(columns=columns, index=np.arange(numdays))

# %%
# Iterate through all 365 days

assert len(start_datetimes) == len(end_datetimes)

for i in tqdm(range(len(start_datetimes))):

    start = start_datetimes[i]
    end = end_datetimes[i]

    results = query_JPL_horizons(start, end)  # type(row)=tuple

    # Save new row to DataFrame
    newrow = dict(zip(columns, results))
    df.loc[i] = newrow
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 365/365 [03:39<00:00,  1.66it/s]

# %%
# print(start, end)

# # Set epoch to query
# epoch =  {'start':start.strftime('%Y-%m-%d %H:%M:%S'), 'stop':end.strftime('%Y-%m-%d %H:%M:%S'), 'step':'1m'}

# # Send query
# obj = Horizons(id='sun', location='T17', epochs=epoch) # t17 = Keck II
# result = obj.ephemerides(skip_daylight=True)

# display( result[0] )
# display( result[-1] )

# display(result['datetime_str'][-1])

# %%
# Save lookup table

df.to_csv('/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool/twilight_ephemerides_keckII_2027_test.csv', index=False)

# %%
# Check results for script vs notebook

testdf1 = pd.read_csv('/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool/twilight_ephemerides_keckII_2027_test.csv', names=columns)
testdf2 = pd.read_csv('/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool/twilight_ephemerides_keckII_2027.csv', names=columns)

print( np.sum(testdf1==testdf2) )
# Out:
# Date                366
# sunrise_UTC         365
# sunrise_az          365
# sunrise_el          365
# sunrise_ra          365
# sunrise_dec         365
# sunrise_sidereal    365
# sunset_UTC          365
# sunset_az           365
# sunset_el           365
# sunset_ra           365
# sunset_dec          365
# sunset_sidereal     365
# dtype: int64
# /Users/isabelkain/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %% [markdown]
# ### Query sunrise location

# %%
# Current time
now = datetime.now()
today_date = now.strftime('%Y-%m-%d')
today_year = now.strftime('%Y')
print(today_date)

# Read in solar ephemerides
ephem = pd.read_csv(f'{ephempath}/twilight_ephemerides_keckII_{today_year}.csv')
ephem.head()
# Out:
# 2026-06-21
#          Date         sunset_UTC   sunset_az  sunset_el  sunset_ra  \
# 0  2026-01-01  2026-Jan-01 04:04  246.600173  -2.992473  281.67914
# 1  2026-01-02  2026-Jan-02 04:05  246.723392  -3.077608  282.78250
# 2  2026-01-03  2026-Jan-03 04:05  246.774287  -2.945471  283.88363
# 3  2026-01-04  2026-Jan-04 04:06  246.912751  -3.028147  284.98395
# 4  2026-01-05  2026-Jan-05 04:07  247.058780  -3.109876  286.08258
#
#    sunset_dec  sunset_sidereal        sunrise_UTC  sunrise_az  sunrise_el  \
# 0   -23.00434         0.423682  2026-Jan-01 16:47  113.369118   -2.946773
# 1   -22.91841         0.506108  2026-Jan-02 16:47  113.247551   -3.015929
# 2   -22.82495         0.571822  2026-Jan-03 16:47  113.119382   -3.081303
# 3   -22.72388         0.654248  2026-Jan-04 16:48  113.064502   -2.926429
# 4   -22.61531         0.736672  2026-Jan-05 16:48  112.923256   -2.983823
#
#    sunrise_ra  sunrise_dec  sunrise_sidereal
# 0   282.26860    -22.95972         13.175168
# 1   283.37043    -22.86983         13.240882
# 2   284.47074    -22.77238         13.306595
# 3   285.57017    -22.66734         13.389020
# 4   286.66710    -22.55489         13.454732

# %%
# Shop sunrise & sunset times and az angles
sunset_UTC, sunset_az, _, _, _, _, sunrise_UTC, sunrise_az, _, _, _, _, = read_solar_ephemeris()

print(sunset_UTC, sunset_az)
print(sunrise_UTC, sunrise_az)
# Out:
# Sunset time: 2026-Jun-21 05:14
# Sunrise time: 2026-Jun-21 15:34
# 2026-Jun-21 05:14 296.271155
# 2026-Jun-21 15:34 63.783561

# %% [markdown]
# ### Do object coordinates and conversions

# %%
# Remind myself how to convert between RA/DEC and AZ/EL using astropy coordinates
# This tutorial is helpful:
# https://docs.astropy.org/en/stable/coordinates/example_gallery_plot_obs_planning.html#sphx-glr-generated-examples-coordinates-plot-obs-planning-py

keck = EarthLocation.of_site('Keck') # EarthLocation.get_site_names()
keck
# Out:
# <EarthLocation (-5464487.81759887, -2492806.59108569, 2151240.19451846) m>

# %%
# help(get_body)

sun_coord = get_sun(time) # sun_coord.ra.value, sun_coord.dec.value
sun_coord_altaz = sun_coord.transform_to(AltAz(obstime=time, location=keck))

jup_coord = get_body('jupiter', time=time, location=keck) # get_body does moon, sun, and SS planets, not satellites (e.g. Titan)
sat_coord = get_body('saturn', time=time, location=keck) 
nep_coord = get_body('neptune', time=time, location=keck) 
urn_coord = get_body('uranus', time=time, location=keck)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # help(get_body)
# ----> 3 sun_coord = get_sun(time) # sun_coord.ra.value, sun_coord.dec.value
#       4 sun_coord_altaz = sun_coord.transform_to(AltAz(obstime=time, location=keck))
#       6 jup_coord = get_body('jupiter', time=time, location=keck) # get_body does moon, sun, and SS planets, not satellites (e.g. Titan)
#
# NameError: name 'time' is not defined

# %%
# help(get_sun)
sun_coord = get_sun(time)

# %%
# Find object coords (deg)
obj_coord = SkyCoord.from_name("M33")
# m33 = SkyCoord(23.46206906, 30.66017511, unit="deg")

# Set observatory location
keck = EarthLocation.of_site('Keck')

# Set observing time
time = Time(datetime.now())
display(time)

# Convert coordinate from ra/dec to alt/az
# QUESTION: am I sure that Keck alt/az coordinates match whatever astropy things? e.g. the zeroes line up?
obj_coord_altaz = obj_coord.transform_to(AltAz(obstime=time, location=keck))
obj_az = obj_coord_altaz.az.value # degrees
obj_el = obj_coord_altaz.alt.value # degrees
print(obj_az, obj_el)
print(sunrise_az)

# Check telescope, twilight visibility
twi_point = twilight_pointing_limits(obj_az, sunrise_az, az_sep=45.)
tel_point = keckII_pointing_limits(obj_az, obj_el)
print(twi_point, tel_point)
# Out:
# <Time object: scale='utc' format='datetime' value=2026-06-19 13:05:45.904296>
# 63.900580503392824 22.42595620411966
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 18
#      16 obj_el = obj_coord_altaz.alt.value # degrees
#      17 print(obj_az, obj_el)
# ---> 18 print(sunrise_az)
#      20 # Check telescope, twilight visibility
#      21 twi_point = twilight_pointing_limits(obj_az, sunrise_az, az_sep=45.)
#
# NameError: name 'sunrise_az' is not defined

# %%
# Plot object trace, with Keck II and sunrise pointing limits

nep_az, nep_el, trace_times = grab_ss_trace('Neptune', keck, sunset_UTC, sunrise_UTC)

fig = make_azel_plot(sunset_UTC, sunset_az, sunrise_UTC, sunrise_az, 
                     nep_az, nep_el, trace_times, obj_label='Neptune')

plt.show()
# Out:
# 0 9
# /var/folders/g5/srrydzk50l3bltv80n_3n8z80000gn/T/ipykernel_6103/3494512599.py:193: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
datestr = 'today' # %b %d
# date = datetime.strptime(datestr, '%b %d')
# date.year


list_of_dtformats_today = ['today', 'tonight', 'now']

# for fmt in list_of_dtformats_today:
#     if (fmt.casefold() in datestr):
#         print('Success')
# Out:
# Success

# %%
## Make little function to flexibly parse a datestring




datestr = 'JUNE 9'
print('Test string:', datestr)
parse_datestring(datestr)
# Out:
# Test string: JUNE 9
# User-entered observation date: 2026-06-09 00:00:00
# (datetime.datetime(2026, 6, 9, 0, 0), '2026')

# %%
# datestr = 'today'
# print('Test string:', datestr)
# date, year = parse_datestring(datestr)
# display( date, year )


# datetime.date(year=now.year, month=now.month, day=now.day)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 7
#       1 # datestr = 'today'
#       2 # print('Test string:', datestr)
#       3 # date, year = parse_datestring(datestr)
#       4 # display( date, year )
# ----> 7 datetime.date(year=now.year, month=now.month, day=now.day)
#
# TypeError: unbound method datetime.date() needs an argument

# %%
read_solar_ephemeris('2026-01-05')
# Out:
# Multiple rows for the same date. Something went wrong for the 2026-01-05 00:00:00 ephemeris!
# 0

# %%
ephem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 ephem
#
# NameError: name 'ephem' is not defined

# %% [markdown]
# ### Match visibility of TOIs

# %%
toi_list = pd.read_csv('/Users/isabelkain/Desktop/Twilight_/twilight-observing-tool/exofop_tess(1).csv', 
                       skiprows=2, on_bad_lines='warn')
toi_list
# Out:
# Skipping line 15: expected 28 fields, saw 29
# Skipping line 16: expected 28 fields, saw 29
# Skipping line 17: expected 28 fields, saw 29
# Skipping line 28: expected 28 fields, saw 29
# Skipping line 39: expected 28 fields, saw 29
# Skipping line 50: expected 28 fields, saw 29
# Skipping line 61: expected 28 fields, saw 29
# Skipping line 72: expected 28 fields, saw 29
# Skipping line 83: expected 28 fields, saw 29
# Skipping line 94: expected 28 fields, saw 30
# Skipping line 95: expected 28 fields, saw 29
# Skipping line 96: expected 28 fields, saw 29
# Skipping line 97: expected 28 fields, saw 29
# Skipping line 98: expected 28 fields, saw 29
# Skipping line 99: expected 28 fields, saw 29
# Skipping line 100: expected 28 fields, saw 29
# Skipping line 101: expected 28 fields, saw 29
# Skipping line 102: expected 28 fields, saw 29
# Skipping line 103: expected 28 fields, saw 29
# Skipping line 104: expected 28 fields, saw 29
# Skipping line 105: expected 28 fields, saw 29
# Skipping line 116: expected 28 fields, saw 29
# Skipping line 127: expected 28 fields, saw 29
# Skipping line 138: expected 28 fields, saw 29
# Skipping line 149: expected 28 fields, saw 29
# Skipping line 160: expected 28 fields, saw 29
# Skipping line 171: expected 28 fields, saw 29
# Skipping line 183: expected 28 fields, saw 29
# Skipping line 227: expected 28 fields, saw 30
# Skipping line 228: expected 28 fields, saw 30
# Skipping line 229: expected 28 fields, saw 30
# Skipping line 230: expected 28 fields, saw 30
# Skipping line 231: expected 28 fields, saw 30
# Skipping line 232: expected 28 fields, saw 30
# Skipping line 233: expected 28 fields, saw 30
# Skipping line 241: expected 28 fields, saw 29
# Skipping line 242: expected 28 fields, saw 29
# Skipping line 243: expected 28 fields, saw 29
# Skipping line 244: expected 28 fields, saw 29
# Skipping line 245: expected 28 fields, saw 29
# Skipping line 246: expected 28 fields, saw 29
# Skipping line 247: expected 28 fields, saw 29
# Skipping line 340: expected 28 fields, saw 29
# Skipping line 341: expected 28 fields, saw 29
# Skipping line 342: expected 28 fields, saw 29
# Skipping line 343: expected 28 fields, saw 29
# Skipping line 344: expected 28 fields, saw 29
# Skipping line 345: expected 28 fields, saw 29
# Skipping line 346: expected 28 fields, saw 29
# Skipping line 347: expected 28 fields, saw 29
# Skipping line 368: expected 28 fields, saw 30
# Skipping line 413: expected 28 fields, saw 29
# Skipping line 493: expected 28 fields, saw 29
# Skipping line 494: expected 28 fields, saw 29
# Skipping line 495: expected 28 fields, saw 29
# Skipping line 508: expected 28 fields, saw 29
# Skipping line 510: expected 28 fields, saw 29
# Skipping line 512: expected 28 fields, saw 29
# Skipping line 514: expected 28 fields, saw 29
# Skipping line 516: expected 28 fields, saw 29
# Skipping line 518: expected 28 fields, saw 29
# Skipping line 520: expected 28 fields, saw 29
# Skipping line 522: expected 28 fields, saw 29
# Skipping line 524: expected 28 fields, saw 29
# Skipping line 526: expected 28 fields, saw 29
# Skipping line 528: expected 28 fields, saw 29
# Skipping line 530: expected 28 fields, saw 29
# Skipping line 532: expected 28 fields, saw 29
# Skipping line 648: expected 28 fields, saw 29
# Skipping line 650: expected 28 fields, saw 29
# Skipping line 652: expected 28 fields, saw 29
# Skipping line 665: expected 28 fields, saw 29
# Skipping line 666: expected 28 fields, saw 29
# Skipping line 667: expected 28 fields, saw 29
# Skipping line 668: expected 28 fields, saw 29
# Skipping line 669: expected 28 fields, saw 29
# Skipping line 670: expected 28 fields, saw 29
# Skipping line 671: expected 28 fields, saw 29
# Skipping line 672: expected 28 fields, saw 29
# Skipping line 673: expected 28 fields, saw 29
# Skipping line 674: expected 28 fields, saw 29
# Skipping line 690: expected 28 fields, saw 30
# Skipping line 691: expected 28 fields, saw 30
# Skipping line 692: expected 28 fields, saw 30
# Skipping line 693: expected 28 fields, saw 30
# Skipping line 694: expected 28 fields, saw 30
# Skipping line 727: expected 28 fields, saw 30
# Skipping line 741: expected 28 fields, saw 29
# Skipping line 742: expected 28 fields, saw 30
# Skipping line 750: expected 28 fields, saw 29
# Skipping line 751: expected 28 fields, saw 29
# Skipping line 752: expected 28 fields, saw 29
# Skipping line 753: expected 28 fields, saw 29
# Skipping line 754: expected 28 fields, saw 29
# Skipping line 755: expected 28 fields, saw 29
# Skipping line 756: expected 28 fields, saw 29
# Skipping line 757: expected 28 fields, saw 29
# Skipping line 758: expected 28 fields, saw 29
# Skipping line 759: expected 28 fields, saw 29
# Skipping line 808: expected 28 fields, saw 34
# Skipping line 809: expected 28 fields, saw 34
# Skipping line 810: expected 28 fields, saw 34
# Skipping line 811: expected 28 fields, saw 34
# Skipping line 812: expected 28 fields, saw 34
# Skipping line 813: expected 28 fields, saw 34
# Skipping line 814: expected 28 fields, saw 34
# Skipping line 815: expected 28 fields, saw 34
# Skipping line 816: expected 28 fields, saw 34
# Skipping line 891: expected 28 fields, saw 30
# Skipping line 896: expected 28 fields, saw 30
# Skipping line 901: expected 28 fields, saw 30
# Skipping line 904: expected 28 fields, saw 29
# Skipping line 907: expected 28 fields, saw 29
# Skipping line 910: expected 28 fields, saw 29
# Skipping line 913: expected 28 fields, saw 29
# Skipping line 944: expected 28 fields, saw 29
# Skipping line 945: expected 28 fields, saw 29
# Skipping line 946: expected 28 fields, saw 29
# Skipping line 969: expected 28 fields, saw 29
# Skipping line 970: expected 28 fields, saw 29
# Skipping line 971: expected 28 fields, saw 29
# Skipping line 972: expected 28 fields, saw 29
# Skipping line 973: expected 28 fields, saw 29
# Skipping line 974: expected 28 fields, saw 29
# Skipping line 975: expected 28 fields, saw 29
# Skipping line 976: expected 28 fields, saw 29
# Skipping line 977: expected 28 fields, saw 29
# Skipping line 978: expected 28 fields, saw 29
# Skipping line 979: expected 28 fields, saw 29
# Skipping line 1033: expected 28 fields, saw 29
# Skipping line 1034: expected 28 fields, saw 29
# Skipping line 1035: expected 28 fields, saw 29
# Skipping line 1036: expected 28 fields, saw 29
# Skipping line 1037: expected 28 fields, saw 29
# Skipping line 1038: expected 28 fields, saw 29
# Skipping line 1039: expected 28 fields, saw 29
# Skipping line 1040: expected 28 fields, saw 29
# Skipping line 1041: expected 28 fields, saw 29
# Skipping line 1042: expected 28 fields, saw 29
# Skipping line 1043: expected 28 fields, saw 29
# Skipping line 1044: expected 28 fields, saw 29
# Skipping line 1045: expected 28 fields, saw 29
# Skipping line 1187: expected 28 fields, saw 29
# Skipping line 1196: expected 28 fields, saw 30
# Skipping line 1197: expected 28 fields, saw 30
# Skipping line 1199: expected 28 fields, saw 29
# Skipping line 1205: expected 28 fields, saw 29
# Skipping line 1206: expected 28 fields, saw 29
# Skipping line 1207: expected 28 fields, saw 29
# Skipping line 1208: expected 28 fields, saw 29
# Skipping line 1209: expected 28 fields, saw 29
# Skipping line 1210: expected 28 fields, saw 29
# Skipping line 1211: expected 28 fields, saw 29
# Skipping line 1212: expected 28 fields, saw 29
# Skipping line 1213: expected 28 fields, saw 29
# Skipping line 1214: expected 28 fields, saw 29
# Skipping line 1215: expected 28 fields, saw 29
# Skipping line 1216: expected 28 fields, saw 29
# Skipping line 1217: expected 28 fields, saw 29
# Skipping line 1218: expected 28 fields, saw 29
# Skipping line 1220: expected 28 fields, saw 29
# Skipping line 1232: expected 28 fields, saw 30
# Skipping line 1233: expected 28 fields, saw 30
# Skipping line 1278: expected 28 fields, saw 29
# Skipping line 1279: expected 28 fields, saw 29
# Skipping line 1280: expected 28 fields, saw 29
# Skipping line 1310: expected 28 fields, saw 29
# Skipping line 1497: expected 28 fields, saw 29
# Skipping line 1498: expected 28 fields, saw 30
# Skipping line 1504: expected 28 fields, saw 29
# Skipping line 1513: expected 28 fields, saw 29
# Skipping line 1515: expected 28 fields, saw 29
# Skipping line 1540: expected 28 fields, saw 29
# Skipping line 1542: expected 28 fields, saw 30
# Skipping line 1543: expected 28 fields, saw 31
# Skipping line 1544: expected 28 fields, saw 30
# Skipping line 1546: expected 28 fields, saw 29
# Skipping line 1549: expected 28 fields, saw 29
# Skipping line 1613: expected 28 fields, saw 29
# Skipping line 1617: expected 28 fields, saw 29
# Skipping line 1621: expected 28 fields, saw 29
# Skipping line 1625: expected 28 fields, saw 29
# Skipping line 1629: expected 28 fields, saw 29
# Skipping line 1633: expected 28 fields, saw 29
# Skipping line 1637: expected 28 fields, saw 29
# Skipping line 1641: expected 28 fields, saw 29
# Skipping line 1643: expected 28 fields, saw 29
# Skipping line 1645: expected 28 fields, saw 29
# Skipping line 1647: expected 28 fields, saw 29
# Skipping line 1649: expected 28 fields, saw 29
# Skipping line 1651: expected 28 fields, saw 29
# Skipping line 1652: expected 28 fields, saw 29
# Skipping line 1653: expected 28 fields, saw 29
# Skipping line 1654: expected 28 fields, saw 29
# Skipping line 1655: expected 28 fields, saw 29
# Skipping line 1656: expected 28 fields, saw 29
# Skipping line 1657: expected 28 fields, saw 29
# Skipping line 1658: expected 28 fields, saw 29
# Skipping line 1659: expected 28 fields, saw 29
# Skipping line 1660: expected 28 fields, saw 29
# Skipping line 1661: expected 28 fields, saw 29
# Skipping line 1662: expected 28 fields, saw 29
# Skipping line 1663: expected 28 fields, saw 29
# Skipping line 1664: expected 28 fields, saw 29
# Skipping line 1665: expected 28 fields, saw 29
# Skipping line 1666: expected 28 fields, saw 29
# Skipping line 1667: expected 28 fields, saw 29
# Skipping line 1668: expected 28 fields, saw 29
# Skipping line 1679: expected 28 fields, saw 29
# Skipping line 1680: expected 28 fields, saw 29
# Skipping line 1681: expected 28 fields, saw 29
# Skipping line 1682: expected 28 fields, saw 29
# Skipping line 1770: expected 28 fields, saw 29
# Skipping line 1771: expected 28 fields, saw 29
# Skipping line 1772: expected 28 fields, saw 29
# Skipping line 1773: expected 28 fields, saw 29
# Skipping line 1774: expected 28 fields, saw 29
# Skipping line 1775: expected 28 fields, saw 29
# Skipping line 1780: expected 28 fields, saw 29
# Skipping line 1785: expected 28 fields, saw 29
# Skipping line 1790: expected 28 fields, saw 30
# Skipping line 1791: expected 28 fields, saw 29
# Skipping line 1792: expected 28 fields, saw 29
# Skipping line 1793: expected 28 fields, saw 29
# Skipping line 1794: expected 28 fields, saw 29
# Skipping line 1795: expected 28 fields, saw 30
# Skipping line 1796: expected 28 fields, saw 29
# Skipping line 1797: expected 28 fields, saw 29
# Skipping line 1798: expected 28 fields, saw 29
# Skipping line 1799: expected 28 fields, saw 29
# Skipping line 1800: expected 28 fields, saw 30
# Skipping line 1801: expected 28 fields, saw 29
# Skipping line 1802: expected 28 fields, saw 29
# Skipping line 1803: expected 28 fields, saw 29
# Skipping line 1804: expected 28 fields, saw 29
# Skipping line 1805: expected 28 fields, saw 29
# Skipping line 1810: expected 28 fields, saw 29
# Skipping line 1815: expected 28 fields, saw 29
# Skipping line 1911: expected 28 fields, saw 30
# Skipping line 1912: expected 28 fields, saw 29
# Skipping line 1913: expected 28 fields, saw 29
# Skipping line 1914: expected 28 fields, saw 30
# Skipping line 1915: expected 28 fields, saw 29
# Skipping line 1916: expected 28 fields, saw 29
# Skipping line 1917: expected 28 fields, saw 29
# Skipping line 1920: expected 28 fields, saw 29
# Skipping line 1923: expected 28 fields, saw 29
# Skipping line 1926: expected 28 fields, saw 29
# Skipping line 1934: expected 28 fields, saw 29
# Skipping line 1986: expected 28 fields, saw 31
# Skipping line 1987: expected 28 fields, saw 30
# Skipping line 1988: expected 28 fields, saw 30
# Skipping line 1989: expected 28 fields, saw 30
# Skipping line 1990: expected 28 fields, saw 29
# Skipping line 1994: expected 28 fields, saw 29
# Skipping line 1998: expected 28 fields, saw 29
# Skipping line 2002: expected 28 fields, saw 30
# Skipping line 2003: expected 28 fields, saw 29
# Skipping line 2004: expected 28 fields, saw 29
# Skipping line 2005: expected 28 fields, saw 29
# Skipping line 2006: expected 28 fields, saw 29
# Skipping line 2010: expected 28 fields, saw 29
# Skipping line 2014: expected 28 fields, saw 29
# Skipping line 2018: expected 28 fields, saw 29
# Skipping line 2022: expected 28 fields, saw 31
# Skipping line 2023: expected 28 fields, saw 30
# Skipping line 2024: expected 28 fields, saw 30
# Skipping line 2025: expected 28 fields, saw 30
# Skipping line 2026: expected 28 fields, saw 29
# Skipping line 2030: expected 28 fields, saw 29
# Skipping line 2034: expected 28 fields, saw 29
# Skipping line 2038: expected 28 fields, saw 30
# Skipping line 2039: expected 28 fields, saw 29
# Skipping line 2040: expected 28 fields, saw 29
# Skipping line 2041: expected 28 fields, saw 29
# Skipping line 2042: expected 28 fields, saw 29
# Skipping line 2046: expected 28 fields, saw 29
# Skipping line 2050: expected 28 fields, saw 29
# Skipping line 2054: expected 28 fields, saw 29
# Skipping line 2058: expected 28 fields, saw 31
# Skipping line 2059: expected 28 fields, saw 30
# Skipping line 2060: expected 28 fields, saw 30
# Skipping line 2061: expected 28 fields, saw 30
# Skipping line 2062: expected 28 fields, saw 29
# Skipping line 2066: expected 28 fields, saw 29
# Skipping line 2070: expected 28 fields, saw 29
# Skipping line 2074: expected 28 fields, saw 30
# Skipping line 2075: expected 28 fields, saw 29
# Skipping line 2076: expected 28 fields, saw 29
# Skipping line 2077: expected 28 fields, saw 29
# Skipping line 2078: expected 28 fields, saw 29
# Skipping line 2082: expected 28 fields, saw 29
# Skipping line 2086: expected 28 fields, saw 29
# Skipping line 2090: expected 28 fields, saw 29
# Skipping line 2096: expected 28 fields, saw 29
# Skipping line 2099: expected 28 fields, saw 29
# Skipping line 2102: expected 28 fields, saw 29
# Skipping line 2105: expected 28 fields, saw 29
# Skipping line 2108: expected 28 fields, saw 29
# Skipping line 2111: expected 28 fields, saw 29
# Skipping line 2188: expected 28 fields, saw 29
# Skipping line 2194: expected 28 fields, saw 30
# Skipping line 2205: expected 28 fields, saw 30
# Skipping line 2233: expected 28 fields, saw 29
# Skipping line 2234: expected 28 fields, saw 29
# Skipping line 2235: expected 28 fields, saw 29
# Skipping line 2236: expected 28 fields, saw 29
# Skipping line 2237: expected 28 fields, saw 29
# Skipping line 2238: expected 28 fields, saw 29
# Skipping line 2239: expected 28 fields, saw 29
# Skipping line 2240: expected 28 fields, saw 29
# Skipping line 2241: expected 28 fields, saw 29
# Skipping line 2242: expected 28 fields, saw 29
# Skipping line 2243: expected 28 fields, saw 29
# Skipping line 2244: expected 28 fields, saw 29
# Skipping line 2245: expected 28 fields, saw 29
# Skipping line 2270: expected 28 fields, saw 29
# Skipping line 2271: expected 28 fields, saw 33
# Skipping line 2272: expected 28 fields, saw 29
# Skipping line 2273: expected 28 fields, saw 29
# Skipping line 2274: expected 28 fields, saw 29
# Skipping line 2275: expected 28 fields, saw 29
# Skipping line 2276: expected 28 fields, saw 29
# Skipping line 2277: expected 28 fields, saw 29
# Skipping line 2278: expected 28 fields, saw 29
# Skipping line 2279: expected 28 fields, saw 33
# Skipping line 2280: expected 28 fields, saw 29
# Skipping line 2281: expected 28 fields, saw 29
# Skipping line 2282: expected 28 fields, saw 29
# Skipping line 2283: expected 28 fields, saw 29
# Skipping line 2284: expected 28 fields, saw 29
# Skipping line 2285: expected 28 fields, saw 29
# Skipping line 2286: expected 28 fields, saw 29
# Skipping line 2287: expected 28 fields, saw 33
# Skipping line 2288: expected 28 fields, saw 29
# Skipping line 2289: expected 28 fields, saw 29
# Skipping line 2290: expected 28 fields, saw 29
# Skipping line 2291: expected 28 fields, saw 29
# Skipping line 2292: expected 28 fields, saw 29
# Skipping line 2293: expected 28 fields, saw 29
# Skipping line 2334: expected 28 fields, saw 29
# Skipping line 2335: expected 28 fields, saw 29
# Skipping line 2336: expected 28 fields, saw 29
# Skipping line 2337: expected 28 fields, saw 29
# Skipping line 2370: expected 28 fields, saw 29
# Skipping line 2371: expected 28 fields, saw 29
# Skipping line 2372: expected 28 fields, saw 29
# Skipping line 2373: expected 28 fields, saw 29
# Skipping line 2390: expected 28 fields, saw 30
# Skipping line 2391: expected 28 fields, saw 30
# Skipping line 2523: expected 28 fields, saw 29
# Skipping line 2525: expected 28 fields, saw 33
# Skipping line 2526: expected 28 fields, saw 32
# Skipping line 2527: expected 28 fields, saw 29
# Skipping line 2529: expected 28 fields, saw 29
# Skipping line 2531: expected 28 fields, saw 29
# Skipping line 2533: expected 28 fields, saw 29
# Skipping line 2590: expected 28 fields, saw 29
# Skipping line 2591: expected 28 fields, saw 29
# Skipping line 2592: expected 28 fields, saw 29
# Skipping line 2593: expected 28 fields, saw 30
# Skipping line 2594: expected 28 fields, saw 30
# Skipping line 2595: expected 28 fields, saw 30
# Skipping line 2643: expected 28 fields, saw 29
# Skipping line 2644: expected 28 fields, saw 29
# Skipping line 2645: expected 28 fields, saw 29
# Skipping line 2646: expected 28 fields, saw 29
# Skipping line 2647: expected 28 fields, saw 29
# Skipping line 2649: expected 28 fields, saw 33
# Skipping line 2668: expected 28 fields, saw 29
# Skipping line 2682: expected 28 fields, saw 29
# Skipping line 2685: expected 28 fields, saw 29
# Skipping line 2688: expected 28 fields, saw 29
# Skipping line 2691: expected 28 fields, saw 29
# Skipping line 2694: expected 28 fields, saw 29
# Skipping line 2697: expected 28 fields, saw 29
# Skipping line 2698: expected 28 fields, saw 30
# Skipping line 2699: expected 28 fields, saw 30
# Skipping line 2700: expected 28 fields, saw 31
# Skipping line 2701: expected 28 fields, saw 30
# Skipping line 2702: expected 28 fields, saw 30
# Skipping line 2703: expected 28 fields, saw 31
# Skipping line 2704: expected 28 fields, saw 30
# Skipping line 2705: expected 28 fields, saw 30
# Skipping line 2706: expected 28 fields, saw 31
# Skipping line 2715: expected 28 fields, saw 29
# Skipping line 2716: expected 28 fields, saw 29
# Skipping line 2717: expected 28 fields, saw 29
# Skipping line 2718: expected 28 fields, saw 29
# Skipping line 2780: expected 28 fields, saw 29
# Skipping line 2782: expected 28 fields, saw 29
# Skipping line 2784: expected 28 fields, saw 29
# Skipping line 2794: expected 28 fields, saw 29
# Skipping line 2797: expected 28 fields, saw 31
# Skipping line 2798: expected 28 fields, saw 31
# Skipping line 2799: expected 28 fields, saw 31
# Skipping line 2800: expected 28 fields, saw 31
# Skipping line 2801: expected 28 fields, saw 31
# Skipping line 2802: expected 28 fields, saw 31
# Skipping line 2803: expected 28 fields, saw 29
# Skipping line 2806: expected 28 fields, saw 31
# Skipping line 2807: expected 28 fields, saw 31
# Skipping line 2808: expected 28 fields, saw 31
# Skipping line 2809: expected 28 fields, saw 31
# Skipping line 2810: expected 28 fields, saw 31
# Skipping line 2811: expected 28 fields, saw 31
# Skipping line 2812: expected 28 fields, saw 29
# Skipping line 2815: expected 28 fields, saw 31
# Skipping line 2816: expected 28 fields, saw 31
# Skipping line 2817: expected 28 fields, saw 31
# Skipping line 2818: expected 28 fields, saw 31
# Skipping line 2819: expected 28 fields, saw 31
# Skipping line 2820: expected 28 fields, saw 31
# Skipping line 2821: expected 28 fields, saw 29
# Skipping line 2824: expected 28 fields, saw 31
# Skipping line 2825: expected 28 fields, saw 31
# Skipping line 2826: expected 28 fields, saw 31
# Skipping line 2827: expected 28 fields, saw 31
# Skipping line 2828: expected 28 fields, saw 31
# Skipping line 2829: expected 28 fields, saw 31
# Skipping line 2830: expected 28 fields, saw 29
# Skipping line 2833: expected 28 fields, saw 31
# Skipping line 2834: expected 28 fields, saw 31
# Skipping line 2835: expected 28 fields, saw 31
# Skipping line 2836: expected 28 fields, saw 31
# Skipping line 2837: expected 28 fields, saw 31
# Skipping line 2838: expected 28 fields, saw 31
# Skipping line 2839: expected 28 fields, saw 29
# Skipping line 2842: expected 28 fields, saw 31
# Skipping line 2843: expected 28 fields, saw 31
# Skipping line 2844: expected 28 fields, saw 31
# Skipping line 2845: expected 28 fields, saw 31
# Skipping line 2846: expected 28 fields, saw 31
# Skipping line 2847: expected 28 fields, saw 31
# Skipping line 2848: expected 28 fields, saw 29
# Skipping line 2851: expected 28 fields, saw 31
# Skipping line 2852: expected 28 fields, saw 31
# Skipping line 2853: expected 28 fields, saw 31
# Skipping line 2854: expected 28 fields, saw 31
# Skipping line 2855: expected 28 fields, saw 31
# Skipping line 2856: expected 28 fields, saw 31
# Skipping line 2857: expected 28 fields, saw 29
# Skipping line 2860: expected 28 fields, saw 31
# Skipping line 2861: expected 28 fields, saw 31
# Skipping line 2862: expected 28 fields, saw 31
# Skipping line 2863: expected 28 fields, saw 31
# Skipping line 2864: expected 28 fields, saw 31
# Skipping line 2865: expected 28 fields, saw 31
# Skipping line 2866: expected 28 fields, saw 29
# Skipping line 2869: expected 28 fields, saw 31
# Skipping line 2870: expected 28 fields, saw 31
# Skipping line 2871: expected 28 fields, saw 31
# Skipping line 2872: expected 28 fields, saw 31
# Skipping line 2873: expected 28 fields, saw 31
# Skipping line 2874: expected 28 fields, saw 31
# Skipping line 2875: expected 28 fields, saw 29
# Skipping line 2878: expected 28 fields, saw 31
# Skipping line 2879: expected 28 fields, saw 31
# Skipping line 2880: expected 28 fields, saw 31
# Skipping line 2881: expected 28 fields, saw 31
# Skipping line 2882: expected 28 fields, saw 31
# Skipping line 2883: expected 28 fields, saw 31
# Skipping line 2884: expected 28 fields, saw 29
# Skipping line 2887: expected 28 fields, saw 31
# Skipping line 2888: expected 28 fields, saw 31
# Skipping line 2889: expected 28 fields, saw 31
# Skipping line 2890: expected 28 fields, saw 31
# Skipping line 2891: expected 28 fields, saw 31
# Skipping line 2892: expected 28 fields, saw 31
# Skipping line 2893: expected 28 fields, saw 29
# Skipping line 2896: expected 28 fields, saw 31
# Skipping line 2897: expected 28 fields, saw 31
# Skipping line 2898: expected 28 fields, saw 31
# Skipping line 2899: expected 28 fields, saw 31
# Skipping line 2900: expected 28 fields, saw 31
# Skipping line 2901: expected 28 fields, saw 31
# Skipping line 2902: expected 28 fields, saw 29
# Skipping line 2905: expected 28 fields, saw 31
# Skipping line 2906: expected 28 fields, saw 31
# Skipping line 2907: expected 28 fields, saw 31
# Skipping line 2908: expected 28 fields, saw 31
# Skipping line 2909: expected 28 fields, saw 31
# Skipping line 2910: expected 28 fields, saw 31
# Skipping line 2911: expected 28 fields, saw 29
# Skipping line 2914: expected 28 fields, saw 31
# Skipping line 2915: expected 28 fields, saw 31
# Skipping line 2916: expected 28 fields, saw 31
# Skipping line 2917: expected 28 fields, saw 31
# Skipping line 2918: expected 28 fields, saw 31
# Skipping line 2919: expected 28 fields, saw 31
# Skipping line 2920: expected 28 fields, saw 29
# Skipping line 2923: expected 28 fields, saw 31
# Skipping line 2924: expected 28 fields, saw 31
# Skipping line 2925: expected 28 fields, saw 31
# Skipping line 2926: expected 28 fields, saw 31
# Skipping line 2927: expected 28 fields, saw 31
# Skipping line 2928: expected 28 fields, saw 31
# Skipping line 2929: expected 28 fields, saw 29
# Skipping line 2932: expected 28 fields, saw 31
# Skipping line 2933: expected 28 fields, saw 31
# Skipping line 2934: expected 28 fields, saw 31
# Skipping line 2935: expected 28 fields, saw 31
# Skipping line 2936: expected 28 fields, saw 31
# Skipping line 2937: expected 28 fields, saw 31
# Skipping line 2938: expected 28 fields, saw 29
# Skipping line 2941: expected 28 fields, saw 31
# Skipping line 2942: expected 28 fields, saw 31
# Skipping line 2943: expected 28 fields, saw 31
# Skipping line 2944: expected 28 fields, saw 31
# Skipping line 2945: expected 28 fields, saw 31
# Skipping line 2946: expected 28 fields, saw 31
# Skipping line 2947: expected 28 fields, saw 29
# Skipping line 2950: expected 28 fields, saw 31
# Skipping line 2951: expected 28 fields, saw 31
# Skipping line 2952: expected 28 fields, saw 31
# Skipping line 2953: expected 28 fields, saw 31
# Skipping line 2954: expected 28 fields, saw 31
# Skipping line 2955: expected 28 fields, saw 31
# Skipping line 2956: expected 28 fields, saw 29
# Skipping line 2959: expected 28 fields, saw 31
# Skipping line 2960: expected 28 fields, saw 31
# Skipping line 2961: expected 28 fields, saw 31
# Skipping line 2962: expected 28 fields, saw 31
# Skipping line 2963: expected 28 fields, saw 31
# Skipping line 2964: expected 28 fields, saw 31
# Skipping line 2965: expected 28 fields, saw 29
# Skipping line 2968: expected 28 fields, saw 31
# Skipping line 2969: expected 28 fields, saw 31
# Skipping line 2970: expected 28 fields, saw 31
# Skipping line 2971: expected 28 fields, saw 31
# Skipping line 2972: expected 28 fields, saw 31
# Skipping line 2973: expected 28 fields, saw 31
# Skipping line 2974: expected 28 fields, saw 29
# Skipping line 2977: expected 28 fields, saw 31
# Skipping line 2978: expected 28 fields, saw 31
# Skipping line 2979: expected 28 fields, saw 31
# Skipping line 2980: expected 28 fields, saw 31
# Skipping line 2981: expected 28 fields, saw 31
# Skipping line 2982: expected 28 fields, saw 31
# Skipping line 2983: expected 28 fields, saw 29
# Skipping line 2986: expected 28 fields, saw 31
# Skipping line 2987: expected 28 fields, saw 31
# Skipping line 2988: expected 28 fields, saw 31
# Skipping line 2989: expected 28 fields, saw 31
# Skipping line 2990: expected 28 fields, saw 31
# Skipping line 2991: expected 28 fields, saw 31
# Skipping line 2992: expected 28 fields, saw 29
# Skipping line 2995: expected 28 fields, saw 31
# Skipping line 2996: expected 28 fields, saw 31
# Skipping line 2997: expected 28 fields, saw 31
# Skipping line 2998: expected 28 fields, saw 31
# Skipping line 2999: expected 28 fields, saw 31
# Skipping line 3000: expected 28 fields, saw 31
# Skipping line 3001: expected 28 fields, saw 29
# Skipping line 3004: expected 28 fields, saw 31
# Skipping line 3005: expected 28 fields, saw 31
# Skipping line 3006: expected 28 fields, saw 31
# Skipping line 3007: expected 28 fields, saw 31
# Skipping line 3008: expected 28 fields, saw 31
# Skipping line 3009: expected 28 fields, saw 31
# Skipping line 3010: expected 28 fields, saw 29
# Skipping line 3013: expected 28 fields, saw 31
# Skipping line 3014: expected 28 fields, saw 31
# Skipping line 3015: expected 28 fields, saw 31
# Skipping line 3016: expected 28 fields, saw 31
# Skipping line 3017: expected 28 fields, saw 31
# Skipping line 3018: expected 28 fields, saw 31
# Skipping line 3019: expected 28 fields, saw 29
# Skipping line 3022: expected 28 fields, saw 31
# Skipping line 3023: expected 28 fields, saw 31
# Skipping line 3024: expected 28 fields, saw 31
# Skipping line 3025: expected 28 fields, saw 31
# Skipping line 3026: expected 28 fields, saw 31
# Skipping line 3027: expected 28 fields, saw 31
# Skipping line 3028: expected 28 fields, saw 29
# Skipping line 3031: expected 28 fields, saw 31
# Skipping line 3032: expected 28 fields, saw 31
# Skipping line 3033: expected 28 fields, saw 31
# Skipping line 3034: expected 28 fields, saw 31
# Skipping line 3035: expected 28 fields, saw 31
# Skipping line 3036: expected 28 fields, saw 31
# Skipping line 3037: expected 28 fields, saw 29
# Skipping line 3040: expected 28 fields, saw 31
# Skipping line 3041: expected 28 fields, saw 31
# Skipping line 3042: expected 28 fields, saw 31
# Skipping line 3043: expected 28 fields, saw 31
# Skipping line 3044: expected 28 fields, saw 31
# Skipping line 3045: expected 28 fields, saw 31
# Skipping line 3046: expected 28 fields, saw 29
# Skipping line 3049: expected 28 fields, saw 31
# Skipping line 3050: expected 28 fields, saw 31
# Skipping line 3051: expected 28 fields, saw 31
# Skipping line 3052: expected 28 fields, saw 31
# Skipping line 3053: expected 28 fields, saw 31
# Skipping line 3054: expected 28 fields, saw 31
# Skipping line 3055: expected 28 fields, saw 29
# Skipping line 3058: expected 28 fields, saw 31
# Skipping line 3059: expected 28 fields, saw 31
# Skipping line 3060: expected 28 fields, saw 31
# Skipping line 3061: expected 28 fields, saw 31
# Skipping line 3062: expected 28 fields, saw 31
# Skipping line 3063: expected 28 fields, saw 31
# Skipping line 3064: expected 28 fields, saw 29
# Skipping line 3067: expected 28 fields, saw 31
# Skipping line 3068: expected 28 fields, saw 31
# Skipping line 3069: expected 28 fields, saw 31
# Skipping line 3070: expected 28 fields, saw 31
# Skipping line 3071: expected 28 fields, saw 31
# Skipping line 3072: expected 28 fields, saw 31
# Skipping line 3073: expected 28 fields, saw 29
# Skipping line 3076: expected 28 fields, saw 31
# Skipping line 3077: expected 28 fields, saw 31
# Skipping line 3078: expected 28 fields, saw 31
# Skipping line 3079: expected 28 fields, saw 31
# Skipping line 3080: expected 28 fields, saw 31
# Skipping line 3081: expected 28 fields, saw 31
# Skipping line 3082: expected 28 fields, saw 29
# Skipping line 3085: expected 28 fields, saw 31
# Skipping line 3086: expected 28 fields, saw 31
# Skipping line 3087: expected 28 fields, saw 31
# Skipping line 3088: expected 28 fields, saw 31
# Skipping line 3089: expected 28 fields, saw 31
# Skipping line 3090: expected 28 fields, saw 31
# Skipping line 3091: expected 28 fields, saw 29
# Skipping line 3094: expected 28 fields, saw 31
# Skipping line 3095: expected 28 fields, saw 31
# Skipping line 3096: expected 28 fields, saw 31
# Skipping line 3097: expected 28 fields, saw 31
# Skipping line 3098: expected 28 fields, saw 31
# Skipping line 3099: expected 28 fields, saw 31
# Skipping line 3100: expected 28 fields, saw 29
# Skipping line 3108: expected 28 fields, saw 29
# Skipping line 3116: expected 28 fields, saw 29
# Skipping line 3124: expected 28 fields, saw 29
# Skipping line 3132: expected 28 fields, saw 30
# Skipping line 3133: expected 28 fields, saw 29
# Skipping line 3134: expected 28 fields, saw 29
# Skipping line 3135: expected 28 fields, saw 29
# Skipping line 3136: expected 28 fields, saw 29
# Skipping line 3137: expected 28 fields, saw 29
# Skipping line 3138: expected 28 fields, saw 29
# Skipping line 3139: expected 28 fields, saw 29
# Skipping line 3140: expected 28 fields, saw 30
# Skipping line 3141: expected 28 fields, saw 29
# Skipping line 3142: expected 28 fields, saw 29
# Skipping line 3143: expected 28 fields, saw 29
# Skipping line 3144: expected 28 fields, saw 29
# Skipping line 3145: expected 28 fields, saw 29
# Skipping line 3146: expected 28 fields, saw 29
# Skipping line 3147: expected 28 fields, saw 29
# Skipping line 3148: expected 28 fields, saw 29
# Skipping line 3156: expected 28 fields, saw 29
# Skipping line 3164: expected 28 fields, saw 29
# Skipping line 3165: expected 28 fields, saw 29
# Skipping line 3166: expected 28 fields, saw 29
# Skipping line 3170: expected 28 fields, saw 29
# Skipping line 3171: expected 28 fields, saw 29
# Skipping line 3172: expected 28 fields, saw 29
# Skipping line 3217: expected 28 fields, saw 29
# Skipping line 3218: expected 28 fields, saw 30
# Skipping line 3227: expected 28 fields, saw 29
# Skipping line 3228: expected 28 fields, saw 29
# Skipping line 3229: expected 28 fields, saw 29
# Skipping line 3230: expected 28 fields, saw 29
# Skipping line 3231: expected 28 fields, saw 29
# Skipping line 3232: expected 28 fields, saw 29
# Skipping line 3256: expected 28 fields, saw 29
# Skipping line 3257: expected 28 fields, saw 29
# Skipping line 3258: expected 28 fields, saw 29
# Skipping line 3259: expected 28 fields, saw 29
# Skipping line 3260: expected 28 fields, saw 29
# Skipping line 3261: expected 28 fields, saw 29
# Skipping line 3262: expected 28 fields, saw 29
# Skipping line 3263: expected 28 fields, saw 29
# Skipping line 3264: expected 28 fields, saw 29
# Skipping line 3265: expected 28 fields, saw 29
# Skipping line 3266: expected 28 fields, saw 29
# Skipping line 3267: expected 28 fields, saw 29
# Skipping line 3268: expected 28 fields, saw 29
# Skipping line 3269: expected 28 fields, saw 29
# Skipping line 3270: expected 28 fields, saw 29
# Skipping line 3271: expected 28 fields, saw 29
# Skipping line 3272: expected 28 fields, saw 29
# Skipping line 3273: expected 28 fields, saw 29
# Skipping line 3274: expected 28 fields, saw 29
# Skipping line 3275: expected 28 fields, saw 29
# Skipping line 3276: expected 28 fields, saw 29
# Skipping line 3277: expected 28 fields, saw 29
# Skipping line 3278: expected 28 fields, saw 29
# Skipping line 3279: expected 28 fields, saw 29
# Skipping line 3280: expected 28 fields, saw 29
# Skipping line 3284: expected 28 fields, saw 29
# Skipping line 3288: expected 28 fields, saw 30
# Skipping line 3289: expected 28 fields, saw 29
# Skipping line 3290: expected 28 fields, saw 29
# Skipping line 3291: expected 28 fields, saw 29
# Skipping line 3292: expected 28 fields, saw 30
# Skipping line 3293: expected 28 fields, saw 29
# Skipping line 3294: expected 28 fields, saw 29
# Skipping line 3295: expected 28 fields, saw 29
# Skipping line 3296: expected 28 fields, saw 29
# Skipping line 3306: expected 28 fields, saw 29
# Skipping line 3307: expected 28 fields, saw 29
# Skipping line 3308: expected 28 fields, saw 29
# Skipping line 3309: expected 28 fields, saw 29
# Skipping line 3310: expected 28 fields, saw 29
# Skipping line 3311: expected 28 fields, saw 29
# Skipping line 3312: expected 28 fields, saw 29
# Skipping line 3313: expected 28 fields, saw 29
# Skipping line 3314: expected 28 fields, saw 29
# Skipping line 3315: expected 28 fields, saw 29
# Skipping line 3316: expected 28 fields, saw 29
# Skipping line 3317: expected 28 fields, saw 29
# Skipping line 3318: expected 28 fields, saw 29
# Skipping line 3339: expected 28 fields, saw 29
# Skipping line 3340: expected 28 fields, saw 29
# Skipping line 3341: expected 28 fields, saw 29
# Skipping line 3342: expected 28 fields, saw 29
# Skipping line 3343: expected 28 fields, saw 29
# Skipping line 3344: expected 28 fields, saw 29
# Skipping line 3345: expected 28 fields, saw 29
# Skipping line 3346: expected 28 fields, saw 29
# Skipping line 3347: expected 28 fields, saw 29
# Skipping line 3348: expected 28 fields, saw 29
# Skipping line 3349: expected 28 fields, saw 29
# Skipping line 3350: expected 28 fields, saw 29
# Skipping line 3351: expected 28 fields, saw 29
# Skipping line 3372: expected 28 fields, saw 29
# Skipping line 3374: expected 28 fields, saw 29
# Skipping line 3377: expected 28 fields, saw 29
# Skipping line 3378: expected 28 fields, saw 29
# Skipping line 3381: expected 28 fields, saw 30
# Skipping line 3382: expected 28 fields, saw 30
# Skipping line 3383: expected 28 fields, saw 30
# Skipping line 3384: expected 28 fields, saw 29
# Skipping line 3385: expected 28 fields, saw 29
# Skipping line 3387: expected 28 fields, saw 29
# Skipping line 3390: expected 28 fields, saw 29
# Skipping line 3391: expected 28 fields, saw 29
# Skipping line 3394: expected 28 fields, saw 30
# Skipping line 3395: expected 28 fields, saw 30
# Skipping line 3396: expected 28 fields, saw 30
# Skipping line 3397: expected 28 fields, saw 29
# Skipping line 3398: expected 28 fields, saw 29
# Skipping line 3400: expected 28 fields, saw 29
# Skipping line 3403: expected 28 fields, saw 29
# Skipping line 3404: expected 28 fields, saw 29
# Skipping line 3407: expected 28 fields, saw 30
# Skipping line 3408: expected 28 fields, saw 30
# Skipping line 3409: expected 28 fields, saw 30
# Skipping line 3410: expected 28 fields, saw 29
# Skipping line 3411: expected 28 fields, saw 30
# Skipping line 3412: expected 28 fields, saw 29
# Skipping line 3413: expected 28 fields, saw 30
# Skipping line 3414: expected 28 fields, saw 29
# Skipping line 3415: expected 28 fields, saw 29
# Skipping line 3416: expected 28 fields, saw 30
# Skipping line 3417: expected 28 fields, saw 30
# Skipping line 3418: expected 28 fields, saw 29
# Skipping line 3419: expected 28 fields, saw 29
# Skipping line 3420: expected 28 fields, saw 31
# Skipping line 3421: expected 28 fields, saw 31
# Skipping line 3422: expected 28 fields, saw 31
# Skipping line 3423: expected 28 fields, saw 30
# Skipping line 3424: expected 28 fields, saw 29
# Skipping line 3426: expected 28 fields, saw 29
# Skipping line 3429: expected 28 fields, saw 29
# Skipping line 3430: expected 28 fields, saw 29
# Skipping line 3433: expected 28 fields, saw 30
# Skipping line 3434: expected 28 fields, saw 30
# Skipping line 3435: expected 28 fields, saw 30
# Skipping line 3436: expected 28 fields, saw 29
# Skipping line 3437: expected 28 fields, saw 29
# Skipping line 3439: expected 28 fields, saw 29
# Skipping line 3442: expected 28 fields, saw 29
# Skipping line 3443: expected 28 fields, saw 29
# Skipping line 3446: expected 28 fields, saw 30
# Skipping line 3447: expected 28 fields, saw 30
# Skipping line 3448: expected 28 fields, saw 30
# Skipping line 3449: expected 28 fields, saw 29
# Skipping line 3450: expected 28 fields, saw 29
# Skipping line 3452: expected 28 fields, saw 29
# Skipping line 3455: expected 28 fields, saw 29
# Skipping line 3456: expected 28 fields, saw 29
# Skipping line 3459: expected 28 fields, saw 30
# Skipping line 3460: expected 28 fields, saw 30
# Skipping line 3461: expected 28 fields, saw 30
# Skipping line 3462: expected 28 fields, saw 29
# Skipping line 3463: expected 28 fields, saw 29
# Skipping line 3465: expected 28 fields, saw 29
# Skipping line 3468: expected 28 fields, saw 29
# Skipping line 3469: expected 28 fields, saw 29
# Skipping line 3472: expected 28 fields, saw 30
# Skipping line 3473: expected 28 fields, saw 30
# Skipping line 3474: expected 28 fields, saw 30
# Skipping line 3475: expected 28 fields, saw 29
# Skipping line 3476: expected 28 fields, saw 29
# Skipping line 3478: expected 28 fields, saw 29
# Skipping line 3481: expected 28 fields, saw 29
# Skipping line 3482: expected 28 fields, saw 29
# Skipping line 3485: expected 28 fields, saw 30
# Skipping line 3486: expected 28 fields, saw 30
# Skipping line 3487: expected 28 fields, saw 30
# Skipping line 3488: expected 28 fields, saw 29
# Skipping line 3489: expected 28 fields, saw 29
# Skipping line 3491: expected 28 fields, saw 29
# Skipping line 3494: expected 28 fields, saw 29
# Skipping line 3495: expected 28 fields, saw 29
# Skipping line 3498: expected 28 fields, saw 30
# Skipping line 3499: expected 28 fields, saw 30
# Skipping line 3500: expected 28 fields, saw 30
# Skipping line 3501: expected 28 fields, saw 29
# Skipping line 3502: expected 28 fields, saw 29
# Skipping line 3504: expected 28 fields, saw 29
# Skipping line 3507: expected 28 fields, saw 29
# Skipping line 3508: expected 28 fields, saw 29
# Skipping line 3511: expected 28 fields, saw 30
# Skipping line 3512: expected 28 fields, saw 30
# Skipping line 3513: expected 28 fields, saw 30
# Skipping line 3514: expected 28 fields, saw 29
# Skipping line 3515: expected 28 fields, saw 29
# Skipping line 3517: expected 28 fields, saw 29
# Skipping line 3520: expected 28 fields, saw 29
# Skipping line 3521: expected 28 fields, saw 29
# Skipping line 3524: expected 28 fields, saw 30
# Skipping line 3525: expected 28 fields, saw 30
# Skipping line 3526: expected 28 fields, saw 30
# Skipping line 3527: expected 28 fields, saw 29
# Skipping line 3528: expected 28 fields, saw 29
# Skipping line 3530: expected 28 fields, saw 29
# Skipping line 3533: expected 28 fields, saw 29
# Skipping line 3534: expected 28 fields, saw 29
# Skipping line 3537: expected 28 fields, saw 30
# Skipping line 3538: expected 28 fields, saw 30
# Skipping line 3539: expected 28 fields, saw 30
# Skipping line 3540: expected 28 fields, saw 29
# Skipping line 3541: expected 28 fields, saw 29
# Skipping line 3543: expected 28 fields, saw 29
# Skipping line 3546: expected 28 fields, saw 29
# Skipping line 3547: expected 28 fields, saw 29
# Skipping line 3550: expected 28 fields, saw 30
# Skipping line 3551: expected 28 fields, saw 30
# Skipping line 3552: expected 28 fields, saw 30
# Skipping line 3553: expected 28 fields, saw 29
# Skipping line 3554: expected 28 fields, saw 29
# Skipping line 3556: expected 28 fields, saw 29
# Skipping line 3559: expected 28 fields, saw 29
# Skipping line 3560: expected 28 fields, saw 29
# Skipping line 3563: expected 28 fields, saw 30
# Skipping line 3564: expected 28 fields, saw 30
# Skipping line 3565: expected 28 fields, saw 30
# Skipping line 3566: expected 28 fields, saw 29
# Skipping line 3567: expected 28 fields, saw 29
# Skipping line 3569: expected 28 fields, saw 29
# Skipping line 3572: expected 28 fields, saw 29
# Skipping line 3573: expected 28 fields, saw 29
# Skipping line 3576: expected 28 fields, saw 30
# Skipping line 3577: expected 28 fields, saw 30
# Skipping line 3578: expected 28 fields, saw 30
# Skipping line 3579: expected 28 fields, saw 29
# Skipping line 3580: expected 28 fields, saw 29
# Skipping line 3582: expected 28 fields, saw 29
# Skipping line 3585: expected 28 fields, saw 29
# Skipping line 3586: expected 28 fields, saw 29
# Skipping line 3589: expected 28 fields, saw 30
# Skipping line 3590: expected 28 fields, saw 30
# Skipping line 3591: expected 28 fields, saw 30
# Skipping line 3592: expected 28 fields, saw 29
# Skipping line 3593: expected 28 fields, saw 29
# Skipping line 3595: expected 28 fields, saw 29
# Skipping line 3598: expected 28 fields, saw 29
# Skipping line 3599: expected 28 fields, saw 29
# Skipping line 3602: expected 28 fields, saw 30
# Skipping line 3603: expected 28 fields, saw 30
# Skipping line 3604: expected 28 fields, saw 30
# Skipping line 3605: expected 28 fields, saw 29
# Skipping line 3606: expected 28 fields, saw 29
# Skipping line 3608: expected 28 fields, saw 29
# Skipping line 3611: expected 28 fields, saw 29
# Skipping line 3612: expected 28 fields, saw 29
# Skipping line 3615: expected 28 fields, saw 30
# Skipping line 3616: expected 28 fields, saw 30
# Skipping line 3617: expected 28 fields, saw 30
# Skipping line 3618: expected 28 fields, saw 29
# Skipping line 3619: expected 28 fields, saw 29
# Skipping line 3621: expected 28 fields, saw 29
# Skipping line 3624: expected 28 fields, saw 29
# Skipping line 3625: expected 28 fields, saw 29
# Skipping line 3628: expected 28 fields, saw 30
# Skipping line 3629: expected 28 fields, saw 30
# Skipping line 3630: expected 28 fields, saw 30
# Skipping line 3631: expected 28 fields, saw 29
# Skipping line 3632: expected 28 fields, saw 29
# Skipping line 3634: expected 28 fields, saw 29
# Skipping line 3637: expected 28 fields, saw 29
# Skipping line 3638: expected 28 fields, saw 29
# Skipping line 3641: expected 28 fields, saw 30
# Skipping line 3642: expected 28 fields, saw 30
# Skipping line 3643: expected 28 fields, saw 30
# Skipping line 3644: expected 28 fields, saw 29
# Skipping line 3645: expected 28 fields, saw 29
# Skipping line 3647: expected 28 fields, saw 29
# Skipping line 3650: expected 28 fields, saw 29
# Skipping line 3651: expected 28 fields, saw 29
# Skipping line 3654: expected 28 fields, saw 30
# Skipping line 3655: expected 28 fields, saw 30
# Skipping line 3656: expected 28 fields, saw 30
# Skipping line 3657: expected 28 fields, saw 29
# Skipping line 3658: expected 28 fields, saw 29
# Skipping line 3660: expected 28 fields, saw 29
# Skipping line 3663: expected 28 fields, saw 29
# Skipping line 3664: expected 28 fields, saw 29
# Skipping line 3667: expected 28 fields, saw 30
# Skipping line 3668: expected 28 fields, saw 30
# Skipping line 3669: expected 28 fields, saw 30
# Skipping line 3670: expected 28 fields, saw 29
# Skipping line 3671: expected 28 fields, saw 29
# Skipping line 3673: expected 28 fields, saw 29
# Skipping line 3676: expected 28 fields, saw 29
# Skipping line 3677: expected 28 fields, saw 29
# Skipping line 3680: expected 28 fields, saw 30
# Skipping line 3681: expected 28 fields, saw 30
# Skipping line 3682: expected 28 fields, saw 30
# Skipping line 3683: expected 28 fields, saw 29
# Skipping line 3684: expected 28 fields, saw 29
# Skipping line 3686: expected 28 fields, saw 29
# Skipping line 3689: expected 28 fields, saw 29
# Skipping line 3690: expected 28 fields, saw 29
# Skipping line 3693: expected 28 fields, saw 30
# Skipping line 3694: expected 28 fields, saw 30
# Skipping line 3695: expected 28 fields, saw 30
# Skipping line 3696: expected 28 fields, saw 29
# Skipping line 3788: expected 28 fields, saw 29
# Skipping line 3789: expected 28 fields, saw 29
# Skipping line 3813: expected 28 fields, saw 31
# Skipping line 3814: expected 28 fields, saw 31
# Skipping line 3820: expected 28 fields, saw 31
# Skipping line 3821: expected 28 fields, saw 31
# Skipping line 3827: expected 28 fields, saw 31
# Skipping line 3828: expected 28 fields, saw 31
# Skipping line 3834: expected 28 fields, saw 31
# Skipping line 3835: expected 28 fields, saw 31
# Skipping line 3841: expected 28 fields, saw 31
# Skipping line 3842: expected 28 fields, saw 31
# Skipping line 3843: expected 28 fields, saw 31
# Skipping line 3844: expected 28 fields, saw 31
# Skipping line 3845: expected 28 fields, saw 31
# Skipping line 3846: expected 28 fields, saw 31
# Skipping line 3847: expected 28 fields, saw 31
# Skipping line 3848: expected 28 fields, saw 34
# Skipping line 3849: expected 28 fields, saw 34
# Skipping line 3850: expected 28 fields, saw 31
# Skipping line 3851: expected 28 fields, saw 31
# Skipping line 3852: expected 28 fields, saw 31
# Skipping line 3853: expected 28 fields, saw 31
# Skipping line 3854: expected 28 fields, saw 31
# Skipping line 3855: expected 28 fields, saw 34
# Skipping line 3856: expected 28 fields, saw 34
# Skipping line 3862: expected 28 fields, saw 31
# Skipping line 3863: expected 28 fields, saw 31
# Skipping line 3869: expected 28 fields, saw 31
# Skipping line 3870: expected 28 fields, saw 31
# Skipping line 3876: expected 28 fields, saw 31
# Skipping line 3877: expected 28 fields, saw 31
# Skipping line 3885: expected 28 fields, saw 29
# Skipping line 3890: expected 28 fields, saw 29
# Skipping line 3895: expected 28 fields, saw 30
# Skipping line 3896: expected 28 fields, saw 29
# Skipping line 3897: expected 28 fields, saw 29
# Skipping line 3898: expected 28 fields, saw 29
# Skipping line 3899: expected 28 fields, saw 29
# Skipping line 3900: expected 28 fields, saw 30
# Skipping line 3901: expected 28 fields, saw 29
# Skipping line 3902: expected 28 fields, saw 29
# Skipping line 3903: expected 28 fields, saw 29
# Skipping line 3904: expected 28 fields, saw 29
# Skipping line 3905: expected 28 fields, saw 29
# Skipping line 3910: expected 28 fields, saw 29
# Skipping line 3915: expected 28 fields, saw 29
# Skipping line 3916: expected 28 fields, saw 30
# Skipping line 3917: expected 28 fields, saw 30
# Skipping line 3918: expected 28 fields, saw 29
# Skipping line 3919: expected 28 fields, saw 29
# Skipping line 3920: expected 28 fields, saw 30
# Skipping line 3921: expected 28 fields, saw 30
# Skipping line 3922: expected 28 fields, saw 29
# Skipping line 3923: expected 28 fields, saw 29
# Skipping line 3924: expected 28 fields, saw 30
# Skipping line 3925: expected 28 fields, saw 30
# Skipping line 3926: expected 28 fields, saw 29
# Skipping line 3943: expected 28 fields, saw 33
# Skipping line 3944: expected 28 fields, saw 33
# Skipping line 3945: expected 28 fields, saw 33
# Skipping line 3946: expected 28 fields, saw 33
# Skipping line 3947: expected 28 fields, saw 33
# Skipping line 3948: expected 28 fields, saw 33
# Skipping line 3951: expected 28 fields, saw 33
# Skipping line 3952: expected 28 fields, saw 33
# Skipping line 3953: expected 28 fields, saw 33
# Skipping line 3954: expected 28 fields, saw 33
# Skipping line 3955: expected 28 fields, saw 33
# Skipping line 3956: expected 28 fields, saw 33
# Skipping line 3959: expected 28 fields, saw 33
# Skipping line 3960: expected 28 fields, saw 33
# Skipping line 3961: expected 28 fields, saw 33
# Skipping line 3962: expected 28 fields, saw 33
# Skipping line 3963: expected 28 fields, saw 33
# Skipping line 3964: expected 28 fields, saw 33
# Skipping line 3967: expected 28 fields, saw 33
# Skipping line 3968: expected 28 fields, saw 33
# Skipping line 3969: expected 28 fields, saw 33
# Skipping line 3970: expected 28 fields, saw 33
# Skipping line 3971: expected 28 fields, saw 33
# Skipping line 3972: expected 28 fields, saw 33
# Skipping line 3975: expected 28 fields, saw 33
# Skipping line 3976: expected 28 fields, saw 33
# Skipping line 3977: expected 28 fields, saw 33
# Skipping line 3978: expected 28 fields, saw 33
# Skipping line 3979: expected 28 fields, saw 33
# Skipping line 3980: expected 28 fields, saw 33
# Skipping line 3983: expected 28 fields, saw 33
# Skipping line 3984: expected 28 fields, saw 33
# Skipping line 3985: expected 28 fields, saw 33
# Skipping line 3986: expected 28 fields, saw 33
# ...
# Skipping line 20237: expected 28 fields, saw 30
# Skipping line 20238: expected 28 fields, saw 30
# Skipping line 20239: expected 28 fields, saw 29
# Skipping line 20242: expected 28 fields, saw 30
# Skipping line 20243: expected 28 fields, saw 30
# Skipping line 20244: expected 28 fields, saw 30
# Skipping line 20245: expected 28 fields, saw 29
# Skipping line 20276: expected 28 fields, saw 30
# Skipping line 20277: expected 28 fields, saw 30
# Skipping line 20278: expected 28 fields, saw 30
# Skipping line 20284: expected 28 fields, saw 30
# Skipping line 20285: expected 28 fields, saw 30
# Skipping line 20290: expected 28 fields, saw 30
# Skipping line 20291: expected 28 fields, saw 30
# Skipping line 20292: expected 28 fields, saw 30
# Skipping line 20302: expected 28 fields, saw 30
# Skipping line 20303: expected 28 fields, saw 30
# Skipping line 20304: expected 28 fields, saw 30
# Skipping line 20307: expected 28 fields, saw 29
# Skipping line 20315: expected 28 fields, saw 30
# Skipping line 20316: expected 28 fields, saw 30
# Skipping line 20317: expected 28 fields, saw 29
# Skipping line 20321: expected 28 fields, saw 30
# Skipping line 20322: expected 28 fields, saw 30
# Skipping line 20323: expected 28 fields, saw 30
# Skipping line 20324: expected 28 fields, saw 30
# Skipping line 20327: expected 28 fields, saw 30
# Skipping line 20328: expected 28 fields, saw 30
# Skipping line 20338: expected 28 fields, saw 30
# Skipping line 20339: expected 28 fields, saw 30
# Skipping line 20346: expected 28 fields, saw 30
# Skipping line 20347: expected 28 fields, saw 30
# Skipping line 20359: expected 28 fields, saw 31
# Skipping line 20360: expected 28 fields, saw 31
# Skipping line 20361: expected 28 fields, saw 29
# Skipping line 20362: expected 28 fields, saw 29
# Skipping line 20379: expected 28 fields, saw 30
# Skipping line 20381: expected 28 fields, saw 29
# Skipping line 20382: expected 28 fields, saw 29
# Skipping line 20385: expected 28 fields, saw 29
# Skipping line 20392: expected 28 fields, saw 30
# Skipping line 20397: expected 28 fields, saw 29
# Skipping line 20407: expected 28 fields, saw 30
# Skipping line 20408: expected 28 fields, saw 30
# Skipping line 20409: expected 28 fields, saw 30
# Skipping line 20430: expected 28 fields, saw 30
# Skipping line 20431: expected 28 fields, saw 30
# Skipping line 20433: expected 28 fields, saw 30
# Skipping line 20434: expected 28 fields, saw 30
# Skipping line 20435: expected 28 fields, saw 30
# Skipping line 20436: expected 28 fields, saw 30
# Skipping line 20441: expected 28 fields, saw 30
# Skipping line 20442: expected 28 fields, saw 30
# Skipping line 20443: expected 28 fields, saw 30
# Skipping line 20444: expected 28 fields, saw 30
# Skipping line 20445: expected 28 fields, saw 30
# Skipping line 20456: expected 28 fields, saw 30
# Skipping line 20459: expected 28 fields, saw 30
# Skipping line 20464: expected 28 fields, saw 30
# Skipping line 20465: expected 28 fields, saw 30
# Skipping line 20468: expected 28 fields, saw 30
# Skipping line 20469: expected 28 fields, saw 30
# Skipping line 20470: expected 28 fields, saw 30
# Skipping line 20471: expected 28 fields, saw 30
# Skipping line 20472: expected 28 fields, saw 30
# Skipping line 20473: expected 28 fields, saw 30
# Skipping line 20481: expected 28 fields, saw 30
# Skipping line 20482: expected 28 fields, saw 30
# Skipping line 20483: expected 28 fields, saw 30
# Skipping line 20484: expected 28 fields, saw 30
# Skipping line 20489: expected 28 fields, saw 29
# Skipping line 20497: expected 28 fields, saw 30
# Skipping line 20502: expected 28 fields, saw 30
# Skipping line 20503: expected 28 fields, saw 30
# Skipping line 20505: expected 28 fields, saw 30
# Skipping line 20509: expected 28 fields, saw 30
# Skipping line 20516: expected 28 fields, saw 30
# Skipping line 20519: expected 28 fields, saw 30
# Skipping line 20529: expected 28 fields, saw 30
# Skipping line 20539: expected 28 fields, saw 29
# Skipping line 20540: expected 28 fields, saw 29
# Skipping line 20541: expected 28 fields, saw 29
# Skipping line 20542: expected 28 fields, saw 29
# Skipping line 20552: expected 28 fields, saw 31
# Skipping line 20553: expected 28 fields, saw 31
# Skipping line 20554: expected 28 fields, saw 31
# Skipping line 20555: expected 28 fields, saw 30
# Skipping line 20556: expected 28 fields, saw 30
# Skipping line 20557: expected 28 fields, saw 30
# Skipping line 20558: expected 28 fields, saw 30
# Skipping line 20559: expected 28 fields, saw 31
# Skipping line 20560: expected 28 fields, saw 31
# Skipping line 20561: expected 28 fields, saw 31
# Skipping line 20562: expected 28 fields, saw 30
# Skipping line 20563: expected 28 fields, saw 30
# Skipping line 20564: expected 28 fields, saw 30
# Skipping line 20565: expected 28 fields, saw 30
# Skipping line 20566: expected 28 fields, saw 31
# Skipping line 20567: expected 28 fields, saw 31
# Skipping line 20568: expected 28 fields, saw 31
# Skipping line 20569: expected 28 fields, saw 30
# Skipping line 20570: expected 28 fields, saw 30
# Skipping line 20571: expected 28 fields, saw 30
# Skipping line 20572: expected 28 fields, saw 30
# Skipping line 20573: expected 28 fields, saw 31
# Skipping line 20574: expected 28 fields, saw 31
# Skipping line 20575: expected 28 fields, saw 31
# Skipping line 20576: expected 28 fields, saw 30
# Skipping line 20577: expected 28 fields, saw 30
# Skipping line 20578: expected 28 fields, saw 30
# Skipping line 20579: expected 28 fields, saw 30
# Skipping line 20580: expected 28 fields, saw 31
# Skipping line 20581: expected 28 fields, saw 31
# Skipping line 20582: expected 28 fields, saw 31
# Skipping line 20583: expected 28 fields, saw 30
# Skipping line 20584: expected 28 fields, saw 30
# Skipping line 20585: expected 28 fields, saw 30
# Skipping line 20586: expected 28 fields, saw 30
# Skipping line 20587: expected 28 fields, saw 31
# Skipping line 20588: expected 28 fields, saw 31
# Skipping line 20589: expected 28 fields, saw 31
# Skipping line 20590: expected 28 fields, saw 30
# Skipping line 20591: expected 28 fields, saw 30
# Skipping line 20592: expected 28 fields, saw 30
# Skipping line 20593: expected 28 fields, saw 30
# Skipping line 20594: expected 28 fields, saw 31
# Skipping line 20595: expected 28 fields, saw 31
# Skipping line 20596: expected 28 fields, saw 31
# Skipping line 20597: expected 28 fields, saw 30
# Skipping line 20598: expected 28 fields, saw 30
# Skipping line 20599: expected 28 fields, saw 30
# Skipping line 20600: expected 28 fields, saw 30
# Skipping line 20601: expected 28 fields, saw 31
# Skipping line 20602: expected 28 fields, saw 31
# Skipping line 20603: expected 28 fields, saw 31
# Skipping line 20604: expected 28 fields, saw 30
# Skipping line 20605: expected 28 fields, saw 30
# Skipping line 20606: expected 28 fields, saw 30
# Skipping line 20607: expected 28 fields, saw 30
# Skipping line 20609: expected 28 fields, saw 29
# Skipping line 20610: expected 28 fields, saw 29
# Skipping line 20611: expected 28 fields, saw 29
# Skipping line 20612: expected 28 fields, saw 29
# Skipping line 20613: expected 28 fields, saw 29
# Skipping line 20614: expected 28 fields, saw 29
# Skipping line 20621: expected 28 fields, saw 32
# Skipping line 20622: expected 28 fields, saw 32
# Skipping line 20623: expected 28 fields, saw 32
# Skipping line 20624: expected 28 fields, saw 29
# Skipping line 20625: expected 28 fields, saw 32
# Skipping line 20626: expected 28 fields, saw 32
# Skipping line 20627: expected 28 fields, saw 32
# Skipping line 20628: expected 28 fields, saw 29
# Skipping line 20629: expected 28 fields, saw 32
# Skipping line 20630: expected 28 fields, saw 32
# Skipping line 20631: expected 28 fields, saw 32
# Skipping line 20632: expected 28 fields, saw 29
# Skipping line 20633: expected 28 fields, saw 32
# Skipping line 20634: expected 28 fields, saw 32
# Skipping line 20635: expected 28 fields, saw 32
# Skipping line 20636: expected 28 fields, saw 29
# Skipping line 20637: expected 28 fields, saw 32
# Skipping line 20638: expected 28 fields, saw 32
# Skipping line 20639: expected 28 fields, saw 32
# Skipping line 20640: expected 28 fields, saw 29
# Skipping line 20641: expected 28 fields, saw 32
# Skipping line 20642: expected 28 fields, saw 32
# Skipping line 20643: expected 28 fields, saw 32
# Skipping line 20644: expected 28 fields, saw 29
# Skipping line 20645: expected 28 fields, saw 32
# Skipping line 20646: expected 28 fields, saw 32
# Skipping line 20647: expected 28 fields, saw 32
# Skipping line 20648: expected 28 fields, saw 29
# Skipping line 20649: expected 28 fields, saw 31
# Skipping line 20650: expected 28 fields, saw 31
# Skipping line 20651: expected 28 fields, saw 31
# Skipping line 20652: expected 28 fields, saw 31
# Skipping line 20653: expected 28 fields, saw 31
# Skipping line 20654: expected 28 fields, saw 31
# Skipping line 20655: expected 28 fields, saw 31
# Skipping line 20656: expected 28 fields, saw 31
# Skipping line 20657: expected 28 fields, saw 31
# Skipping line 20658: expected 28 fields, saw 31
# Skipping line 20659: expected 28 fields, saw 31
# Skipping line 20660: expected 28 fields, saw 31
# Skipping line 20661: expected 28 fields, saw 31
# Skipping line 20662: expected 28 fields, saw 31
# Skipping line 20663: expected 28 fields, saw 31
# Skipping line 20683: expected 28 fields, saw 29
# Skipping line 20684: expected 28 fields, saw 29
# Skipping line 20685: expected 28 fields, saw 29
# Skipping line 20686: expected 28 fields, saw 29
# Skipping line 20687: expected 28 fields, saw 29
# Skipping line 20688: expected 28 fields, saw 29
# Skipping line 20690: expected 28 fields, saw 29
# Skipping line 20696: expected 28 fields, saw 29
# Skipping line 20697: expected 28 fields, saw 30
# Skipping line 20698: expected 28 fields, saw 31
# Skipping line 20699: expected 28 fields, saw 32
# Skipping line 20700: expected 28 fields, saw 31
# Skipping line 20701: expected 28 fields, saw 32
# Skipping line 20703: expected 28 fields, saw 29
# Skipping line 20709: expected 28 fields, saw 29
# Skipping line 20718: expected 28 fields, saw 29
# Skipping line 20719: expected 28 fields, saw 29
# Skipping line 20720: expected 28 fields, saw 29
# Skipping line 20721: expected 28 fields, saw 29
# Skipping line 20742: expected 28 fields, saw 31
# Skipping line 20750: expected 28 fields, saw 29
# Skipping line 20760: expected 28 fields, saw 29
#           TIC ID      TOI           RA           Dec TFOPWG Disposition  \
# 0      336732616   103.01   20:49:49.8   -24:25:43.3                 KP
# 1      336732616   103.01   20:49:49.8   -24:25:43.3                 KP
# 2      336732616   103.01   20:49:49.8   -24:25:43.3                 KP
# 3      336732616   103.01   20:49:49.8   -24:25:43.3                 KP
# 4      336732616   103.01   20:49:49.8   -24:25:43.3                 KP
# ...          ...      ...          ...           ...                ...
# 15683  285212983  7616.01     07:59:32  -45:27:13.58                 PC
# 15684  385796857  7617.01  07:24:00.49  -15:54:40.14                 PC
# 15685   54391400  7618.01  07:53:24.84  -14:47:58.25                 PC
# 15686  412386707  7619.01   07:21:56.9  -23:24:50.53                 PC
# 15687  130958848  7621.01  07:49:08.14  -37:39:57.41                 PC
#
#        Teff (TOI)  log(g) (TOI)  Stellar Radius (TOI) Imaging Telescope  \
# 0          6351.0       4.22896              1.400000       Wendelstein
# 1          6351.0       4.22896              1.400000       Wendelstein
# 2          6351.0       4.22896              1.400000            Gemini
# 3          6351.0       4.22896              1.400000            Gemini
# 4          6351.0       4.22896              1.400000              SOAR
# ...           ...           ...                   ...               ...
# 15683     10002.0       4.40497              1.662140               NaN
# 15684      6586.0       3.90808              2.154540               NaN
# 15685      4001.0       4.51347              0.721926               NaN
# 15686      6304.0       3.94553              1.961670               NaN
# 15687      6556.0       4.54108              1.035770               NaN
#
#       Imaging Instrument  ... Imaging Contrast separation Imaging Date  \
# 0                    3KK  ...                         NaN   2018-09-05
# 1                    3KK  ...                         NaN   2018-09-05
# 2               'Alopeke  ...                         0.5   2021-06-27
# 3               'Alopeke  ...                         0.5   2021-06-27
# 4                  HRCam  ...                           1   2021-07-14
# ...                  ...  ...                         ...          ...
# 15683                NaN  ...                         NaN          NaN
# 15684                NaN  ...                         NaN          NaN
# 15685                NaN  ...                         NaN          NaN
# 15686                NaN  ...                         NaN          NaN
# 15687                NaN  ...                         NaN          NaN
#
#       Stellar Companion Filter Name Stellar Companion Filter  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 15683                           NaN                      NaN
# 15684                           NaN                      NaN
# 15685                           NaN                      NaN
# 15686                           NaN                      NaN
# 15687                           NaN                      NaN
#
#       Stellar Companion notes  Stellar Companion user  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 15683                     NaN                     NaN
# 15684                     NaN                     NaN
# 15685                     NaN                     NaN
# 15686                     NaN                     NaN
# 15687                     NaN                     NaN
#
#       Stellar Companion Separation Stellar Companion Position angle  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# ...                            ...                              ...
# 15683                          NaN                              NaN
# 15684                          NaN                              NaN
# 15685                          NaN                              NaN
# 15686                          NaN                              NaN
# 15687                          NaN                              NaN
#
#       Stellar Companion Delta mag Stellar Companion Observation date
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ...                           ...                                ...
# 15683                         NaN                                NaN
# 15684                         NaN                                NaN
# 15685                         NaN                                NaN
# 15686                         NaN                                NaN
# 15687                         NaN                                NaN
#
# [15688 rows x 28 columns]

# %%
for toi in toi_list['TOI'].unique():
    print('TOI'+str(int(toi)))
    
    
# TOI103.01, 
# TOI105.01, 
# TOI108.01, 
# TOI109.01, 
# TOI113.01, 
# TOI123.01, 
# TOI126.01, 
# TOI132.01, 
# TOI139.01, 
# TOI143.01, 
# TOI148.01,
# Out:
# TOI103
# TOI105
# TOI108
# TOI109
# TOI113
# TOI7594
# TOI7595
# TOI7596
# TOI7598
# TOI7599
# TOI7600
# TOI7601
# TOI7602
# TOI7603
# TOI7604
# TOI7605
# TOI7606
# TOI7609
# TOI7610
# TOI7611
# TOI7612
# TOI7614
# TOI7616
# TOI7617
# TOI7618
# TOI7619
# TOI7621

# %%
### 

# Read in solar ephemeris for today's date
sunset_UTC, sunset_az, _, _, _, _, sunrise_UTC, sunrise_az, _, _, _, _,  = read_solar_ephemeris()

# Set observatory location
keck = EarthLocation.of_site('Keck')

# Read in (ra, dec) of one TOI host
toi_coord = SkyCoord.from_name("TOI 103.01")
# toi_coord = SkyCoord(toi_list['RA'][0], toi_list['Dec'][0], unit=(u.hourangle, u.deg))

# Convert from (ra, dec) to (az, el) at sunrise from Keck II
toi_coord_azel = toi_coord.transform_to(AltAz(obstime=Time(datetime.strptime(sunrise_UTC, '%Y-%b-%d %H:%M')), location=keck))
toi_az = toi_coord_azel.az.value
toi_el = toi_coord_azel.alt.value
print(toi_az, toi_el)

# Convert from (ra, dec) to (az, el) at sunset from Keck II
toi_coord_azel = toi_coord.transform_to(AltAz(obstime=Time(datetime.strptime(sunset_UTC, '%Y-%b-%d %H:%M')), location=keck))
toi_az = toi_coord_azel.az.value
toi_el = toi_coord_azel.alt.value
print(toi_az, toi_el)
# Out:
# Sunset time: 2026-Jun-21 05:14
# Sunrise time: 2026-Jun-21 15:34
# 219.21796726228308 34.213550587706834
# 106.38718910994062 -35.00184972367188

# %%
# ## Iterate through all unique TOI hosts, check if visible any sunrise of the year
# # multiprocessing

# unique_TOIs = toi_list['TOI'].unique()
# random_tois = np.random.choice(unique_TOIs, 15)
# vis_matrix = np.full((len(unique_TOIs), len(ephem)), False)

# for i, toi_num in tqdm(enumerate(unique_TOIs[:15])):
# # for i, toi_num in tqdm(enumerate(random_TOIs)):
                              
#     # Manually find ra/dec of test TOI
# #     toi_num = random_tois[0]
#     loc = np.where(toi_list['TOI']==toi_num)[0][0] # Find first instance of TOI in table
#     toi_coord = SkyCoord(toi_list['RA'][loc], toi_list['Dec'][loc], unit=(u.hourangle, u.deg))

#     # Try multithreading
#     sunrise_dt_list = [datetime.strptime(ephem['sunrise_UTC'][j], '%Y-%b-%d %H:%M') for j in range(len(ephem))]
#     toi_coord_list = [toi_coord]*len(sunrise_dt_list)
#     keck_site_list = [keck]*len(sunrise_dt_list)

#     # if __name__ == '__main__':
#     vis_matrix_row = []

#     # Initialize pool
#     pool = multiprocessing.Pool(4)

#     # Do multiprocessing for checking if this target is up for each of 365 days of the year
#     for result in pool.starmap(is_target_up_morn_twi, zip(sunrise_dt_list, toi_coord_list, keck_site_list)):
#         vis_matrix_row.append(result)
            
#     # Save as row in visibility matrix
#     vis_matrix[i,:] = vis_matrix_row

    
# # print(len(vis_matrix_row), vis_matrix_row[:5])

# %%
## Iterate through all unique TOI hosts, check if visible any sunrise of the year

# Read in TOI list, ephemeris for this year
year = '2027'
toi_list = pd.read_csv(f'{toipath}/exofop_dec30_companionsep1500mas.csv', skiprows=2, on_bad_lines='skip')
ephem = pd.read_csv(f'{ephempath}/twilight_ephemerides_keckII_{year}.csv')

# Set observatory location
keck = EarthLocation.of_site('Keck')
    
# Isolate unique TOI identifiers
unique_TOIs = toi_list['TOI'].unique()
print(f'{len(unique_TOIs)} unique TOIs.')

# Set up empty matrix to catch boolean visibility results
vis_matrix = np.full((len(unique_TOIs), len(ephem)), False)

# Pull ~4000-long lists of TOI parameters to iterate over using multiprocess
toi_loc_list = [np.where(toi_list['TOI']==toi_num)[0][0] for toi_num in unique_TOIs]
toi_coord_list = [SkyCoord(toi_list['RA'][loc], toi_list['Dec'][loc], unit=(u.hourangle, u.deg)) for loc in toi_loc_list]
keck_site_list = [keck]*len(toi_loc_list)

sunrise_temp = [datetime.strptime(ephem['sunrise_UTC'][j], '%Y-%b-%d %H:%M') for j in range(len(ephem))]
sunrise_list = [sunrise_temp]*len(toi_loc_list) # shape 4000x365


########################
## Do multiprocessing ##
########################

# Initialize pool
pool = multiprocessing.Pool(4)

# Do multiprocessing for checking if this target is up for each of 365 days of the year
for i, result in enumerate(pool.starmap(multiprocess_toi_visibility, zip(toi_coord_list, sunrise_list, keck_site_list))):
    vis_matrix[i, :] = result
    
pool.close() # are these necessary?
pool.join()
# Out:
# 378 unique TOIs.
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
#
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: astropy.samp was deprecated in version 8.0 and will be removed in a future version; please use pyvo.samp instead. [astropy.samp]
# WARNING: AstropyDeprecationWarning: astropy.samp was deprecated in version 8.0 and will be removed in a future version; please use pyvo.samp instead. [astropy.samp]
# WARNING: AstropyDeprecationWarning: astropy.samp was deprecated in version 8.0 and will be removed in a future version; please use pyvo.samp instead. [astropy.samp]
# WARNING: AstropyDeprecationWarning: astropy.samp was deprecated in version 8.0 and will be removed in a future version; please use pyvo.samp instead. [astropy.samp]
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]

# %%
vis_matrix


# Process visibility_matrix, unique_TOIs / random_tois


plt.figure(figsize=(10,10))
plt.imshow(vis_matrix[:,:])

num_days_visible = np.sum(vis_matrix, axis=1)
no_days_visible = num_days_visible==0
print('Number of TOIs never visible in 2027:', np.sum(no_days_visible))



sort_index = np.argsort(num_days_visible)
# print( num_days_visible, np.flip(num_days_visible[sort_index]) )

vis_matrix_sorted = vis_matrix[np.flip(sort_index), :]

plt.figure(figsize=(10,10))
plt.imshow(vis_matrix_sorted[:,:])
# Out:
# Number of TOIs never visible in 2027: 0

# %%
plt.plot( np.sum(vis_matrix, axis=0) )
plt.axhline(0.0, color='k', ls='--')
plt.ylabel('Number of twilight-accessible TOIs per night')
plt.xlabel('2027 nights')
# Out:
# Text(0.5, 0, '2027 nights')

# %%
vis_matrix_sorted

# %%
# ## Iterate through all unique TOI hosts, check if visible any sunrise of the year

# ##########################
# # Multithreading (jump) ##
# ##########################

# # Read in toi_list, ephem

# # global toi_list, ephem

# year = '2025'
# toi_list = pd.read_csv(f'{toipath}/exofop_tess(1).csv', skiprows=2, on_bad_lines='skip')
# ephem = pd.read_csv(f'{ephempath}/twilight_ephemerides_keckII_{year}.csv')

# unique_TOIs = toi_list['TOI'].unique()
# random_tois = np.random.choice(unique_TOIs, 15)
# # vis_matrix = np.full((len(unique_TOIs), len(ephem)), False)
# # global vis_matrix
# vis_matrix = np.array([])

# print(np.shape(vis_matrix))

# # def toplevel(toi_num, site):
# #     '''
# #     Required globals: toi_list, ephem
# #     '''
    
# #     print('New row:', toi_num)
    
# #     # Manually find ra/dec of test TOI
# #     loc = np.where(toi_list['TOI']==toi_num)[0][0] # Find first instance of TOI in table
# #     toi_coord = SkyCoord(toi_list['RA'][loc], toi_list['Dec'][loc], unit=(u.hourangle, u.deg))


# #     # Iterate through 365 days per year, check twilight visibility

# #     vis_matrix_row = []

# #     for j in range(len(ephem)): # for each day in given year

# #         # Grab
# #         sunrise_dt = datetime.strptime(ephem['sunrise_UTC'][j], '%Y-%b-%d %H:%M')
# #         is_up = is_target_up_morn_twi(sunrise_dt, toi_coord, site=keck)

# #         vis_matrix_row[j] = is_up
        
# # #     out_queue.put(vis_matrix_row)
# # #     vis_matrix = np.append(vis_matrix, vis_matrix_row)
# #     return vis_matrix_row
    

    
# # print(len(vis_matrix_row), vis_matrix_row[:5])

# ###############################
# ## Set up multithreading     ##
# ###############################

# import queue
# import time

# # # Initialize task queue
# # task_queue = multiprocessing.Manager().Queue() # queue.Queue()

# # # Issue all top-level tasks
# # for i, toi_num in enumerate(unique_TOIs[:15]):
# #     task_queue.put((toplevel, (toi_num, year, keck)))

# # # Assume we know the total number of tasks
# # total_tasks = 15 #* len(ephem) # len(unique_TOIs) * len(ephem)

# start_time = time.time()

# # create a thread pool
# with multiprocessing.pool.ThreadPool(total_tasks) as pool:

#     # Set up execution of threads
#     toi_num_list = unique_TOIs[:15]
#     year_list = [year]*15
#     keck_site_list = [keck]*15
    
#     # Execute threads
#     print('Starting starmap')
    
#     for result in pool.starmap(visperday, zip(toi_num_list, year_list, keck_site_list)):
#         vis_matrix = np.append(vis_matrix, result)
#         print(np.shape(vis_matrix))
#     print('Finished starmap', np.shape(vis_matrix), time.time()-start_time)
    
#     # close the pool
#     pool.close()
#     print('Closed', time.time()-start_time)
    
#     # wait for all tasks to be processed
#     pool.join()
#     print('Joined', time.time()-start_time)
        
    
# # result = task_queue.get()
# print('Total execution time:', time.time()-start_time)
# # display(np.shape(result), type(result), result)
# print(np.shape(vis_matrix))

# %%
########################################################
## TEST NESTING MULTIPROCESSING(MULTITHREADING)       ##
########################################################

# %%
toi_num_list = unique_TOIs[:15]
year_list = [year]*15
keck_site_list = [keck]*15

print(len(toi_num_list), len(year_list), len(keck_site_list), )
# Out:
# 15 15 15

# %%
## Iterate through all unique TOI hosts, check if visible any sunrise of the year
## NO MULTIPROCESSING TIMING TEST

unique_TOIs = toi_list['TOI'].unique()
random_tois = np.random.choice(unique_TOIs, 15)
vis_matrix = np.full((len(unique_TOIs), len(ephem)), False)

for i, toi_num in tqdm(enumerate(unique_TOIs)):

    if i > 15: break
                              
    # Manually find ra/dec of test TOI
    loc = np.where(toi_list['TOI']==toi_num)[0][0] # Find first instance of TOI in table
    toi_coord = SkyCoord(toi_list['RA'][loc], toi_list['Dec'][loc], unit=(u.hourangle, u.deg))


    for j in range(len(ephem)): # for each day in given year

        # Grab
        sunrise_dt = datetime.strptime(ephem['sunrise_UTC'][j], '%Y-%b-%d %H:%M')
        is_up = is_target_up_morn_twi(sunrise_dt, toi_coord, site=keck)

        vis_matrix[i][j] = is_up
# Out:
# 16it [00:36,  2.28s/it]

# %%
'''
No multiproccessing: ~2.25s/it
Multiprocessing (at date level): ~1.75s/it (twice as fast)
Multiproccessing (at TOI level): ~0.8s/it
Multithreading + multiprocessing: same (~1.75s/it)
'''

# %%
# Process visibility_matrix, unique_TOIs / random_tois


plt.figure(figsize=(10,10))
plt.imshow(vis_matrix[:15,:50])

num_days_visible = np.sum(vis_matrix[:15,:], axis=1)
no_days_visible = num_days_visible==0
display(no_days_visible)



sort_index = np.argsort(num_days_visible)
print( num_days_visible, np.flip(num_days_visible[sort_index]) )

vis_matrix_sorted = vis_matrix[sort_index,:]

plt.figure(figsize=(10,10))
plt.imshow(vis_matrix_sorted[:15,:])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])
# [102  35  97  99  76  95  58  46  59 101  54  59  47  62  95] [102 101  99  97  95  95  76  62  59  59  58  54  47  46  35]

# %%
# Narrow down ExoFOP table to TOIs accessible by Keck for at least 1 night in 2026
# Save that narrowed-down table
# Build visibility matrix for targets
# Make airmass chart for all targets (to sniff check visibility calculation)

# %%
# Return list of TOIs visible on a given night
dateloc = 348
datestr = ephem['Date'][dateloc]

up_today = vis_matrix[:, dateloc]
tois_up_tonight = unique_TOIs[up_today]
tois_up_tonight
# Out:
# array([113.01, 123.01, 132.01, 143.01, 148.01, 172.01])

# %%
# weights = np.flip( np.arange(1, np.shape(vis_matrix)[1]+1)**2 )
random_tois
# Out:
# array([2867.01, 4499.01, 2453.01, 1749.03, 2015.01, 2993.01, 5327.01,
#        1709.01, 7457.01, 2575.01, 2021.01, 2757.01, 6475.01, 1280.01,
#        3409.01])

# %%
# np.flip(num_days_visible)

# help(np.argsort)

help(multiprocessing)
# Out:
# Help on package multiprocessing:
#
# NAME
#     multiprocessing
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/multiprocessing.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     # Package analogous to 'threading.py' but using processes
#     #
#     # multiprocessing/__init__.py
#     #
#     # This package is intended to duplicate the functionality (and much of
#     # the API) of threading.py but uses processes instead of threads.  A
#     # subpackage 'multiprocessing.dummy' has the same API but is a simple
#     # wrapper for 'threading'.
#     #
#     # Copyright (c) 2006-2008, R Oudkerk
#     # Licensed to PSF under a Contributor Agreement.
#     #
#
# PACKAGE CONTENTS
#     connection
#     context
#     dummy (package)
#     forkserver
#     heap
#     managers
#     pool
#     popen_fork
#     popen_forkserver
#     popen_spawn_posix
#     popen_spawn_win32
#     process
#     queues
#     reduction
#     resource_sharer
#     resource_tracker
#     shared_memory
#     sharedctypes
#     spawn
#     synchronize
#     util
#
# SUBMODULES
#     reducer
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         multiprocessing.context.ProcessError
#             multiprocessing.context.AuthenticationError
#             multiprocessing.context.BufferTooShort
#             multiprocessing.context.TimeoutError
#     multiprocessing.process.BaseProcess(builtins.object)
#         multiprocessing.context.Process
#
#     class AuthenticationError(ProcessError)
#      |  Method resolution order:
#      |      AuthenticationError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class BufferTooShort(ProcessError)
#      |  Method resolution order:
#      |      BufferTooShort
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Process(multiprocessing.process.BaseProcess)
#      |  Process(group=None, target=None, name=None, args=(), kwargs={}, *, daemon=None)
#      |
#      |  Method resolution order:
#      |      Process
#      |      multiprocessing.process.BaseProcess
#      |      builtins.object
#      |
#      |  Methods inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __init__(self, group=None, target=None, name=None, args=(), kwargs={}, *, daemon=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  close(self)
#      |      Close the Process object.
#      |
#      |      This method releases resources held by the Process object.  It is
#      |      an error to call this method if the child process is still running.
#      |
#      |  is_alive(self)
#      |      Return whether process is alive
#      |
#      |  join(self, timeout=None)
#      |      Wait until child process terminates
#      |
#      |  kill(self)
#      |      Terminate process; sends SIGKILL signal or uses TerminateProcess()
#      |
#      |  run(self)
#      |      Method to be run in sub-process; can be overridden in sub-class
#      |
#      |  start(self)
#      |      Start child process
#      |
#      |  terminate(self)
#      |      Terminate process; sends SIGTERM signal or uses TerminateProcess()
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from multiprocessing.process.BaseProcess:
#      |
#      |  exitcode
#      |      Return exit code of process or `None` if it has yet to stop
#      |
#      |  ident
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  pid
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  sentinel
#      |      Return a file descriptor (Unix) or handle (Windows) suitable for
#      |      waiting for process termination.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  authkey
#      |
#      |  daemon
#      |      Return whether process is a daemon
#      |
#      |  name
#
#     class ProcessError(builtins.Exception)
#      |  Method resolution order:
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class TimeoutError(ProcessError)
#      |  Method resolution order:
#      |      TimeoutError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     Array(typecode_or_type, size_or_initializer, *, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared array
#
#     Barrier(parties, action=None, timeout=None) method of multiprocessing.context.DefaultContext instance
#         Returns a barrier object
#
#     BoundedSemaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a bounded semaphore object
#
#     Condition(lock=None) method of multiprocessing.context.DefaultContext instance
#         Returns a condition object
#
#     Event() method of multiprocessing.context.DefaultContext instance
#         Returns an event object
#
#     JoinableQueue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Lock() method of multiprocessing.context.DefaultContext instance
#         Returns a non-recursive lock object
#
#     Manager() method of multiprocessing.context.DefaultContext instance
#         Returns a manager associated with a running server process
#
#         The managers methods such as `Lock()`, `Condition()` and `Queue()`
#         can be used to create shared objects.
#
#     Pipe(duplex=True) method of multiprocessing.context.DefaultContext instance
#         Returns two connection object connected by a pipe
#
#     Pool(processes=None, initializer=None, initargs=(), maxtasksperchild=None) method of multiprocessing.context.DefaultContext instance
#         Returns a process pool object
#
#     Queue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     RLock() method of multiprocessing.context.DefaultContext instance
#         Returns a recursive lock object
#
#     RawArray(typecode_or_type, size_or_initializer) method of multiprocessing.context.DefaultContext instance
#         Returns a shared array
#
#     RawValue(typecode_or_type, *args) method of multiprocessing.context.DefaultContext instance
#         Returns a shared object
#
#     Semaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a semaphore object
#
#     SimpleQueue() method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Value(typecode_or_type, *args, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared object
#
#     active_children()
#         Return list of process objects corresponding to live child processes
#
#     allow_connection_pickling() method of multiprocessing.context.DefaultContext instance
#         Install support for sending connections and sockets
#         between processes
#
#     cpu_count() method of multiprocessing.context.DefaultContext instance
#         Returns the number of CPUs in the system
#
#     current_process()
#         Return process object representing the current process
#
#     freeze_support() method of multiprocessing.context.DefaultContext instance
#         Check whether this is a fake forked process in a frozen executable.
#         If so then run code specified by commandline and exit.
#
#     get_all_start_methods() method of multiprocessing.context.DefaultContext instance
#
#     get_context(method=None) method of multiprocessing.context.DefaultContext instance
#
#     get_logger() method of multiprocessing.context.DefaultContext instance
#         Return package logger -- if it does not already exist then
#         it is created.
#
#     get_start_method(allow_none=False) method of multiprocessing.context.DefaultContext instance
#
#     log_to_stderr(level=None) method of multiprocessing.context.DefaultContext instance
#         Turn on logging and add a handler which prints to stderr
#
#     parent_process()
#         Return process object representing the parent process
#
#     set_executable(executable) method of multiprocessing.context.DefaultContext instance
#         Sets the path to a python.exe or pythonw.exe binary used to run
#         child processes instead of sys.executable when using the 'spawn'
#         start method.  Useful for people embedding Python.
#
#     set_forkserver_preload(module_names) method of multiprocessing.context.DefaultContext instance
#         Set list of module names to try to load in forkserver process.
#         This is really just a hint.
#
#     set_start_method(method, force=False) method of multiprocessing.context.DefaultContext instance
#
# DATA
#     __all__ = ['Array', 'AuthenticationError', 'Barrier', 'BoundedSemaphor...
#
# FILE
#     /Users/isabelkain/anaconda3/lib/python3.11/multiprocessing/__init__.py

# %%
# toi = 'TOI ' + str( toi_list['TOI'].unique()[0] )
toi = toi_list['TOI'].unique()[0]
np.where(toi_list['TOI']==toi)[0][0]
# Out:
# 0

# %%
# # Make lists of datetime inputs

def is_target_up_morn_twi(sunrise_dt, obj_coord, site):
    '''
    sunrise_dt :: datetime object, datetime of sunrise at site
    obj_coord ::  SkyCoord (ICRS) of target object
    site :: EarthLocation object of observing site
    '''
    
    # idea: return two bools, is_up_all and is_up_most? so can do prioritization?

    # Sample target visibility at 15 minute increments during hour before sunrise
    twilight_samptimes = [sunrise_dt - timedelta(minutes=15*x) for x in range(0,5)]


    # Check if target is within Keck II pointing limits at each sample time
    sampled_visibility = np.full(len(twilight_samptimes), False)

    for j, time in enumerate(twilight_samptimes):

        # What is az/el location of TOI at given time? 
        obj_coord_azel = obj_coord.transform_to(AltAz(obstime=Time(time), location=site))
        obj_az = obj_coord_azel.az.value
        obj_el = obj_coord_azel.alt.value

        # Is it within telescope pointing constraints?
        vis = keckII_pointing_limits(obj_az, obj_el) # returns True/False
        sampled_visibility[j] = vis

    # is object up for at least 3 of the 5 sampled times?
    is_up = (np.sum(sampled_visibility) >= 3.) # True/False -- FIXME is this the right litmus?
    
    return is_up



sunrise_dt = datetime.strptime(ephem['sunrise_UTC'][0], '%Y-%b-%d %H:%M')
is_up = is_target_up_morn_twi(sunrise_dt, toi_coord, site=keck)
is_up
# Out:
# False

# %%
sunrise_dt.year
# Out:
# 2025

# %%
target_name = 'TOI 103.01'
target_name.upper()
# Out:
# 'TOI 103.01'

# %%
'''
Note to self:

Generate list of TOIs that are visible (1) through the night, & (2) during the twilight window for an entire year.
When script runs, have it first return results for the current/specified date before building and saving the whole 
table.

Same for SS targets:
If no ephemeris  table for current year, grab necessary ephemerides for current/specified day, return that, 
then generate the full ephemeris table for the missing year.

'''
